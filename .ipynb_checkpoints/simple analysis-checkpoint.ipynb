# %% [markdown]
# ## Comparing Results
#
# I am compring differnt prediction models based on mean of absoulote error (MAE) and mean of square error over (MSE) the test set. The best model is random forest.

# %%
compare_result(y_pred,y_test)
# Out:
#                 MAE  RMSE
# Model
# knn            0.66  0.99
# Crude Avrage   0.65  1.00
# Lasso          0.65  1.00
# DNN            0.64  0.99
# Random Forest  0.64  0.97

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.cross_validation import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression,Lasso
from sklearn import neighbors
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt
import statsmodels.api as sm

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
get_ipython().magic('matplotlib inline')
# Out:
# /anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# read Date
director =  '/Users/z002df6/Downloads/'
fln = 'TSE_V1_9709 (1).xlsx'
df = pd.read_excel(director+fln)
keys = ['d', ## day
 'f', # firm 
 'Share_out',# number of shares
 'Mkt_cap',
 'Open', #In a day
 'Low',
 'High',
 'Last',
 'Close',
 'Volume',
 'Ind_buy_count',
 'Ins_buy_count',
 'Ind_sell_count',
 'Ins_sell_count',
 'Ind_buy_volume',
 'Ins_buy_volume',
 'Ind_sell_volume',
 'Ins_sell_volume',
 'Ind_buy_value',
 'Ins_buy_value',
 'Ind_sell_value',
 'Ins_sell_value',
 'Ret_P1',
 'Ret_P3',
 'Ret_P5',
 'Ret_P10',
 'Ret_P20',
 'Ret_P30',
 'Ret_P50',
 'Ret_F1',
 'Ret_F3',
 'Ret_F5',
 'Ret_F10',
 'Ret_F20',
 'Ret_F30',
 'Ret_F50']
df.columns= keys
df.head()


# Ind_buy: individual buyer, Industrial buyer
# volume number os stocks,  value: price* volume 
# Ret_P1, Ret_P3 : return in one day close to close, Return in 3 days ,...
# Ret_F1: return in next 3 days
# Out:
#    d    f  Share_out  Mkt_cap  Open   Low  High  Last  Close   Volume  \
# 0  1  121  120000000   40.236  3382  3341  3382  3343   3353  146.095
# 1  2  121  120000000   39.936  3318  3310  3339  3332   3328  188.085
# 2  3  121  120000000   39.888  3294  3276  3336  3335   3324   66.483
# 3  4  121  120000000   39.156  3369  3195  3369  3195   3263  129.258
# 4  5  121  120000000   38.304  3192  3139  3244  3145   3192  223.011
#
#      ...        Ret_P20    Ret_P30    Ret_P50    Ret_F1    Ret_F3    Ret_F5  \
# 0    ...     -11.716693 -14.768683 -18.675722 -0.745601 -2.684163 -6.829705
# 1    ...      -8.846891 -13.982941 -18.451360 -0.120192 -4.086538 -9.885817
# 2    ...      -7.896924 -12.016940 -21.622259 -1.835138 -6.016847 -6.438026
# 3    ...      -7.511338 -10.822629 -21.202608 -2.175912 -8.090714 -4.719583
# 4    ...      -7.718994 -12.500000 -21.707138 -2.130326 -2.568922 -4.197995
#
#      Ret_F10    Ret_F20    Ret_F30    Ret_F50
# 0 -11.810319 -24.366239 -22.994333 -36.206382
# 1 -14.603365 -21.544471 -22.956731 -35.606971
# 2 -17.509025 -21.299639 -25.631769 -35.409146
# 3 -19.000919 -20.410665 -27.214220 -33.098376
# 4 -19.548872 -17.731830 -22.775689 -31.359649
#
# [5 rows x 36 columns]

# %%
inputs  = keys[2:29]
outputs = ['Ret_F1','Ret_F3']

fig, axes = plt.subplots(nrows=len(inputs), ncols=len(outputs), figsize=(30, 20))
for i,nameo in enumerate(outputs):
    for j,name in enumerate(inputs):
        ax = df.plot.scatter( name,nameo,
                             ax = axes[j][i])
        ax.set(xlabel= name, ylabel=['F1','F2'][i])
plt.tight_layout()
plt.show()

# %%
def CorrMtx(df, dropDuplicates = True):

    df = df.corr()

    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)

    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)


CorrMtx(df, dropDuplicates = True)

# %%
from math import log
inputs  = keys[2:29]
outputs = ['Ret_F1','Ret_F3']
(-df['Ret_F1'].min()*2+df['Ret_F1']).map(log).describe()
# Out:
# count    101001.000000
# mean          4.318201
# std           0.028713
# min           3.624686
# 25%           4.307447
# 50%           4.317284
# 75%           4.326536
# max           4.997646
# Name: Ret_F1, dtype: float64

# %%
inputs  = keys[2:29]
outputs = ['Ret_F1','Ret_F3']
df_normlized = ((df - df.mean(axis =0) )/df.std(axis=0))
print(df_normlized[outputs]).describe().applymap(lambda x: round(x,2))
df_normlized[outputs].hist(density =True,bins =100)
X = np.array(df_normlized[inputs])
y = np.array(df_normlized[outputs])
del df_normlized
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
y_pred = {}
# Out:
#           Ret_F1     Ret_F3
# count  101001.00  101001.00
# mean        0.00       0.00
# std         1.00       1.00
# min       -17.23      -9.28
# 25%        -0.38      -0.47
# 50%        -0.05      -0.09
# 75%         0.27       0.33
# max        33.47      20.90

# %%
outputs
# Out:
# ['Ret_F1', 'Ret_F3']

# %% [markdown]
# ### Crude Average and Linear Model

# %%
avr = y_train.mean(axis=0)
avr = avr[np.newaxis,:]
y_pred['Crude Avrage'] = np.repeat(avr, y_test.shape[0], axis=0)
LM = Lasso(alpha=0.1)
LM.fit(X_train, y_train)
y_pred['Lasso'] = LM.predict(X_test)

# %% [markdown]
# ### Random Forest and K-Nearest Neighbour

# %%
rf = RandomForestRegressor(n_estimators = 200, max_depth = 5)
# Train the model on training data
rf.fit(X_train, y_train)
y_pred['Random Forest'] = rf.predict(X_test)

# %%
knn = neighbors.KNeighborsRegressor(10, weights='distance')
knn.fit(X_train, y_train)
y_pred['knn'] = knn.predict(X_test)

# %% [markdown]
# ### Deep Neural Net

# %%
DNN_model = Sequential()
DNN_model.add(Dense(100,input_dim=X_train.shape[1],init='uniform',activation='relu'))
DNN_model.add(Dropout(0.5))
DNN_model.add(Dense(50,init='uniform',activation='tanh'))
DNN_model.add(Dropout(0.5))
DNN_model.add(Dense(100,init='uniform',activation='relu'))
DNN_model.add(Dropout(0.5))
DNN_model.add(Dense(7,init='uniform',activation='relu'))
DNN_model.add(Dropout(0.5))
DNN_model.add(Dense(len(outputs),init='uniform',activation='linear'))
DNN_model.summary()


# ### Fitting the DNN

mn = X_train.mean(axis=0)
sd = X_train.mean(axis=0)
#model.compile(loss='mean_absolute_error',optimizer='adam',metrics='[accuracy]')
DNN_model.compile(loss='mean_squared_error',optimizer='adam')
history = DNN_model.fit((X_train-mn)/sd,y_train,  
                    validation_data=((X_test-mn)/sd, y_test),
                    epochs =2500,
                    batch_size=100,
                    verbose=2)
y_pred['DNN'] = DNN_model.predict((X_test-mn)/sd)
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, activation="relu", kernel_initializer="uniform", input_dim=27)`
#
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(50, activation="tanh", kernel_initializer="uniform")`
#   after removing the cwd from sys.path.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, activation="relu", kernel_initializer="uniform")`
#
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(7, activation="relu", kernel_initializer="uniform")`
#
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(2, activation="linear", kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               2800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               5100
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 707
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 16
# =================================================================
# Total params: 13,673
# Trainable params: 13,673
# Non-trainable params: 0
# _________________________________________________________________
# Train on 67670 samples, validate on 33331 samples
# Epoch 1/500
#  - 3s - loss: 0.9892 - val_loss: 0.9970
# Epoch 2/500
#  - 2s - loss: 0.9868 - val_loss: 0.9918
# Epoch 3/500
#  - 2s - loss: 0.9855 - val_loss: 0.9916
# Epoch 4/500
#  - 2s - loss: 0.9857 - val_loss: 0.9921
# Epoch 5/500
#  - 2s - loss: 0.9838 - val_loss: 0.9871
# Epoch 6/500
#  - 2s - loss: 0.9829 - val_loss: 0.9885
# Epoch 7/500
#  - 3s - loss: 0.9847 - val_loss: 0.9892
# Epoch 8/500
#  - 3s - loss: 0.9829 - val_loss: 0.9859
# Epoch 9/500
#  - 3s - loss: 0.9832 - val_loss: 0.9880
# Epoch 10/500
#  - 4s - loss: 0.9822 - val_loss: 0.9857
# Epoch 11/500
#  - 4s - loss: 0.9836 - val_loss: 0.9846
# Epoch 12/500
#  - 2s - loss: 0.9822 - val_loss: 0.9868
# Epoch 13/500
#  - 2s - loss: 0.9828 - val_loss: 0.9883
# Epoch 14/500
#  - 2s - loss: 0.9835 - val_loss: 0.9883
# Epoch 15/500
#  - 2s - loss: 0.9839 - val_loss: 0.9901
# Epoch 16/500
#  - 2s - loss: 0.9833 - val_loss: 0.9892
# Epoch 17/500
#  - 3s - loss: 0.9835 - val_loss: 0.9901
# Epoch 18/500
#  - 3s - loss: 0.9820 - val_loss: 0.9872
# Epoch 19/500
#  - 3s - loss: 0.9820 - val_loss: 0.9859
# Epoch 20/500
#  - 2s - loss: 0.9808 - val_loss: 0.9863
# Epoch 21/500
#  - 2s - loss: 0.9816 - val_loss: 0.9866
# Epoch 22/500
#  - 2s - loss: 0.9811 - val_loss: 0.9855
# Epoch 23/500
#  - 2s - loss: 0.9804 - val_loss: 0.9857
# Epoch 24/500
#  - 2s - loss: 0.9798 - val_loss: 0.9853
# Epoch 25/500
#  - 2s - loss: 0.9799 - val_loss: 0.9841
# Epoch 26/500
#  - 2s - loss: 0.9810 - val_loss: 0.9842
# Epoch 27/500
#  - 2s - loss: 0.9801 - val_loss: 0.9863
# Epoch 28/500
#  - 2s - loss: 0.9815 - val_loss: 0.9846
# Epoch 29/500
#  - 2s - loss: 0.9823 - val_loss: 0.9879
# Epoch 30/500
#  - 2s - loss: 0.9822 - val_loss: 0.9877
# Epoch 31/500
#  - 2s - loss: 0.9822 - val_loss: 0.9897
# Epoch 32/500
#  - 2s - loss: 0.9832 - val_loss: 0.9903
# Epoch 33/500
#  - 2s - loss: 0.9830 - val_loss: 0.9870
# Epoch 34/500
#  - 2s - loss: 0.9812 - val_loss: 0.9856
# Epoch 35/500
#  - 2s - loss: 0.9823 - val_loss: 0.9890
# Epoch 36/500
#  - 2s - loss: 0.9827 - val_loss: 0.9875
# Epoch 37/500
#  - 2s - loss: 0.9809 - val_loss: 0.9873
# Epoch 38/500
#  - 2s - loss: 0.9822 - val_loss: 0.9907
# Epoch 39/500
#  - 3s - loss: 0.9815 - val_loss: 0.9822
# Epoch 40/500
#  - 6s - loss: 0.9819 - val_loss: 0.9862
# Epoch 41/500
#  - 2s - loss: 0.9806 - val_loss: 0.9840
# Epoch 42/500
#  - 2s - loss: 0.9815 - val_loss: 0.9892
# Epoch 43/500
#  - 2s - loss: 0.9817 - val_loss: 0.9885
# Epoch 44/500
#  - 2s - loss: 0.9808 - val_loss: 0.9864
# Epoch 45/500
#  - 2s - loss: 0.9803 - val_loss: 0.9848
# Epoch 46/500
#  - 2s - loss: 0.9816 - val_loss: 0.9882
# Epoch 47/500
#  - 2s - loss: 0.9817 - val_loss: 0.9894
# Epoch 48/500
#  - 2s - loss: 0.9834 - val_loss: 0.9883
# Epoch 49/500
#  - 2s - loss: 0.9817 - val_loss: 0.9889
# Epoch 50/500
#  - 2s - loss: 0.9838 - val_loss: 0.9881
# Epoch 51/500
#  - 2s - loss: 0.9820 - val_loss: 0.9929
# Epoch 52/500
#  - 2s - loss: 0.9815 - val_loss: 0.9889
# Epoch 53/500
#  - 2s - loss: 0.9829 - val_loss: 0.9871
# Epoch 54/500
#  - 2s - loss: 0.9821 - val_loss: 0.9880
# Epoch 55/500
#  - 2s - loss: 0.9824 - val_loss: 0.9886
# Epoch 56/500
#  - 2s - loss: 0.9831 - val_loss: 0.9895
# Epoch 57/500
#  - 2s - loss: 0.9821 - val_loss: 0.9871
# Epoch 58/500
#  - 2s - loss: 0.9827 - val_loss: 0.9905
# Epoch 59/500
#  - 2s - loss: 0.9826 - val_loss: 0.9895
# Epoch 60/500
#  - 2s - loss: 0.9821 - val_loss: 0.9871
# Epoch 61/500
#  - 2s - loss: 0.9817 - val_loss: 0.9870
# Epoch 62/500
#  - 2s - loss: 0.9815 - val_loss: 0.9877
# Epoch 63/500
#  - 2s - loss: 0.9815 - val_loss: 0.9854
# Epoch 64/500
#  - 2s - loss: 0.9819 - val_loss: 0.9876
# Epoch 65/500
#  - 2s - loss: 0.9824 - val_loss: 0.9880
# Epoch 66/500
#  - 2s - loss: 0.9829 - val_loss: 0.9914
# Epoch 67/500
#  - 2s - loss: 0.9824 - val_loss: 0.9894
# Epoch 68/500
#  - 2s - loss: 0.9827 - val_loss: 0.9900
# Epoch 69/500
#  - 2s - loss: 0.9828 - val_loss: 0.9895
# Epoch 70/500
#  - 2s - loss: 0.9823 - val_loss: 0.9884
# Epoch 71/500
#  - 2s - loss: 0.9820 - val_loss: 0.9874
# Epoch 72/500
#  - 2s - loss: 0.9832 - val_loss: 0.9903
# Epoch 73/500
#  - 2s - loss: 0.9832 - val_loss: 0.9909
# Epoch 74/500
#  - 2s - loss: 0.9822 - val_loss: 0.9886
# Epoch 75/500
#  - 2s - loss: 0.9824 - val_loss: 0.9871
# Epoch 76/500
#  - 2s - loss: 0.9819 - val_loss: 0.9914
# Epoch 77/500
#  - 2s - loss: 0.9822 - val_loss: 0.9870
# Epoch 78/500
#  - 2s - loss: 0.9813 - val_loss: 0.9914
# Epoch 79/500
#  - 2s - loss: 0.9828 - val_loss: 0.9891
# Epoch 80/500
#  - 2s - loss: 0.9828 - val_loss: 0.9870
# Epoch 81/500
#  - 2s - loss: 0.9820 - val_loss: 0.9840
# Epoch 82/500
#  - 2s - loss: 0.9828 - val_loss: 0.9863
# Epoch 83/500
#  - 2s - loss: 0.9826 - val_loss: 0.9880
# Epoch 84/500
#  - 2s - loss: 0.9834 - val_loss: 0.9897
# Epoch 85/500
#  - 2s - loss: 0.9830 - val_loss: 0.9904
# Epoch 86/500
#  - 2s - loss: 0.9837 - val_loss: 0.9890
# Epoch 87/500
#  - 2s - loss: 0.9819 - val_loss: 0.9854
# Epoch 88/500
#  - 2s - loss: 0.9820 - val_loss: 0.9853
# Epoch 89/500
#  - 2s - loss: 0.9817 - val_loss: 0.9862
# Epoch 90/500
#  - 2s - loss: 0.9829 - val_loss: 0.9887
# Epoch 91/500
#  - 2s - loss: 0.9841 - val_loss: 0.9913
# Epoch 92/500
#  - 2s - loss: 0.9822 - val_loss: 0.9916
# Epoch 93/500
#  - 2s - loss: 0.9826 - val_loss: 0.9905
# Epoch 94/500
#  - 2s - loss: 0.9838 - val_loss: 0.9902
# Epoch 95/500
#  - 2s - loss: 0.9845 - val_loss: 0.9924
# Epoch 96/500
#  - 2s - loss: 0.9838 - val_loss: 0.9910
# Epoch 97/500
#  - 2s - loss: 0.9835 - val_loss: 0.9894
# Epoch 98/500
#  - 2s - loss: 0.9840 - val_loss: 0.9891
# Epoch 99/500
#  - 2s - loss: 0.9843 - val_loss: 0.9920
# Epoch 100/500
#  - 2s - loss: 0.9832 - val_loss: 0.9911
# Epoch 101/500
#  - 2s - loss: 0.9810 - val_loss: 0.9852
# Epoch 102/500
#  - 3s - loss: 0.9824 - val_loss: 0.9891
# Epoch 103/500
#  - 3s - loss: 0.9828 - val_loss: 0.9879
# Epoch 104/500
#  - 3s - loss: 0.9821 - val_loss: 0.9887
# Epoch 105/500
#  - 2s - loss: 0.9805 - val_loss: 0.9851
# Epoch 106/500
#  - 2s - loss: 0.9830 - val_loss: 0.9872
# Epoch 107/500
#  - 2s - loss: 0.9824 - val_loss: 0.9860
# Epoch 108/500
#  - 2s - loss: 0.9823 - val_loss: 0.9894
# Epoch 109/500
#  - 3s - loss: 0.9818 - val_loss: 0.9895
# Epoch 110/500
#  - 3s - loss: 0.9812 - val_loss: 0.9883
# Epoch 111/500
#  - 2s - loss: 0.9828 - val_loss: 0.9858
# Epoch 112/500
#  - 3s - loss: 0.9823 - val_loss: 0.9886
# Epoch 113/500
#  - 2s - loss: 0.9819 - val_loss: 0.9858
# Epoch 114/500
#  - 2s - loss: 0.9823 - val_loss: 0.9879
# Epoch 115/500
#  - 2s - loss: 0.9823 - val_loss: 0.9900
# Epoch 116/500
#  - 3s - loss: 0.9816 - val_loss: 0.9890
# Epoch 117/500
#  - 5s - loss: 0.9831 - val_loss: 0.9896
# Epoch 118/500
#  - 2s - loss: 0.9831 - val_loss: 0.9896
# Epoch 119/500
#  - 2s - loss: 0.9820 - val_loss: 0.9903
# Epoch 120/500
#  - 2s - loss: 0.9802 - val_loss: 0.9889
# Epoch 121/500
#  - 3s - loss: 0.9816 - val_loss: 0.9875
# Epoch 122/500
#  - 2s - loss: 0.9839 - val_loss: 0.9911
# Epoch 123/500
#  - 2s - loss: 0.9825 - val_loss: 0.9876
# Epoch 124/500
#  - 2s - loss: 0.9805 - val_loss: 0.9894
# Epoch 125/500
#  - 2s - loss: 0.9807 - val_loss: 0.9913
# Epoch 126/500
#  - 2s - loss: 0.9813 - val_loss: 0.9901
# Epoch 127/500
#  - 2s - loss: 0.9834 - val_loss: 0.9898
# Epoch 128/500
#  - 2s - loss: 0.9820 - val_loss: 0.9900
# Epoch 129/500
#  - 2s - loss: 0.9823 - val_loss: 0.9916
# Epoch 130/500
#  - 2s - loss: 0.9812 - val_loss: 0.9898
# Epoch 131/500
#  - 2s - loss: 0.9815 - val_loss: 0.9872
# Epoch 132/500
#  - 2s - loss: 0.9816 - val_loss: 0.9867
# Epoch 133/500
#  - 4s - loss: 0.9824 - val_loss: 0.9884
# Epoch 134/500
#  - 2s - loss: 0.9830 - val_loss: 0.9884
# Epoch 135/500
#  - 2s - loss: 0.9818 - val_loss: 0.9870
# Epoch 136/500
#  - 2s - loss: 0.9808 - val_loss: 0.9881
# Epoch 137/500
#  - 2s - loss: 0.9819 - val_loss: 0.9899
# Epoch 138/500
#  - 2s - loss: 0.9835 - val_loss: 0.9902
# Epoch 139/500
#  - 4s - loss: 0.9833 - val_loss: 0.9935
# Epoch 140/500
#  - 4s - loss: 0.9848 - val_loss: 0.9912
# Epoch 141/500
#  - 2s - loss: 0.9831 - val_loss: 0.9910
# Epoch 142/500
#  - 2s - loss: 0.9825 - val_loss: 0.9901
# Epoch 143/500
#  - 2s - loss: 0.9811 - val_loss: 0.9884
# Epoch 144/500
#  - 2s - loss: 0.9818 - val_loss: 0.9920
# Epoch 145/500
#  - 2s - loss: 0.9818 - val_loss: 0.9920
# Epoch 146/500
#  - 2s - loss: 0.9819 - val_loss: 0.9914
# Epoch 147/500
#  - 5s - loss: 0.9816 - val_loss: 0.9902
# Epoch 148/500
#  - 3s - loss: 0.9808 - val_loss: 0.9884
# Epoch 149/500
#  - 2s - loss: 0.9832 - val_loss: 0.9921
# Epoch 150/500
#  - 2s - loss: 0.9825 - val_loss: 0.9868
# Epoch 151/500
#  - 2s - loss: 0.9828 - val_loss: 0.9886
# Epoch 152/500
#  - 4s - loss: 0.9812 - val_loss: 0.9885
# Epoch 153/500
#  - 2s - loss: 0.9830 - val_loss: 0.9902
# Epoch 154/500
#  - 3s - loss: 0.9823 - val_loss: 0.9884
# Epoch 155/500
#  - 3s - loss: 0.9825 - val_loss: 0.9895
# Epoch 156/500
#  - 2s - loss: 0.9816 - val_loss: 0.9915
# Epoch 157/500
#  - 2s - loss: 0.9832 - val_loss: 0.9862
# Epoch 158/500
#  - 2s - loss: 0.9798 - val_loss: 0.9891
# Epoch 159/500
#  - 2s - loss: 0.9803 - val_loss: 0.9868
# Epoch 160/500
#  - 2s - loss: 0.9806 - val_loss: 0.9875
# Epoch 161/500
#  - 2s - loss: 0.9819 - val_loss: 0.9880
# Epoch 162/500
#  - 2s - loss: 0.9825 - val_loss: 0.9859
# Epoch 163/500
#  - 7s - loss: 0.9819 - val_loss: 0.9890
# Epoch 164/500
#  - 8s - loss: 0.9810 - val_loss: 0.9870
# Epoch 165/500
#  - 2s - loss: 0.9807 - val_loss: 0.9878
# Epoch 166/500
#  - 2s - loss: 0.9822 - val_loss: 0.9862
# Epoch 167/500
#  - 10814s - loss: 0.9823 - val_loss: 0.9898
# Epoch 168/500
#  - 15s - loss: 0.9826 - val_loss: 0.9899
# Epoch 169/500
#  - 11s - loss: 0.9804 - val_loss: 0.9912
# Epoch 170/500
#  - 2042s - loss: 0.9809 - val_loss: 0.9865
# Epoch 171/500
#  - 16s - loss: 0.9814 - val_loss: 0.9848
# Epoch 172/500
#  - 13s - loss: 0.9831 - val_loss: 0.9868
# Epoch 173/500
#  - 11s - loss: 0.9824 - val_loss: 0.9886
# Epoch 174/500
#  - 31s - loss: 0.9815 - val_loss: 0.9896
# Epoch 175/500
#  - 3s - loss: 0.9823 - val_loss: 0.9881
# Epoch 176/500
#  - 2s - loss: 0.9824 - val_loss: 0.9949
# Epoch 177/500
#  - 2s - loss: 0.9840 - val_loss: 0.9915
# Epoch 178/500
#  - 3s - loss: 0.9827 - val_loss: 0.9927
# Epoch 179/500
#  - 3s - loss: 0.9830 - val_loss: 0.9903
# Epoch 180/500
#  - 2s - loss: 0.9823 - val_loss: 0.9894
# Epoch 181/500
#  - 2s - loss: 0.9830 - val_loss: 0.9884
# Epoch 182/500
#  - 2s - loss: 0.9814 - val_loss: 0.9872
# Epoch 183/500
#  - 2s - loss: 0.9808 - val_loss: 0.9892
# Epoch 184/500
#  - 2s - loss: 0.9813 - val_loss: 0.9840
# Epoch 185/500
#  - 2s - loss: 0.9811 - val_loss: 0.9867
# Epoch 186/500
#  - 2s - loss: 0.9811 - val_loss: 0.9891
# Epoch 187/500
#  - 2s - loss: 0.9817 - val_loss: 0.9904
# Epoch 188/500
#  - 2s - loss: 0.9814 - val_loss: 0.9892
# Epoch 189/500
#  - 2s - loss: 0.9825 - val_loss: 0.9865
# Epoch 190/500
#  - 2s - loss: 0.9820 - val_loss: 0.9875
# Epoch 191/500
#  - 2s - loss: 0.9837 - val_loss: 0.9878
# Epoch 192/500
#  - 2s - loss: 0.9817 - val_loss: 0.9889
# Epoch 193/500
#  - 2s - loss: 0.9815 - val_loss: 0.9868
# Epoch 194/500
#  - 2s - loss: 0.9812 - val_loss: 0.9835
# Epoch 195/500
#  - 2s - loss: 0.9818 - val_loss: 0.9857
# Epoch 196/500
#  - 2s - loss: 0.9799 - val_loss: 0.9846
# Epoch 197/500
#  - 2s - loss: 0.9801 - val_loss: 0.9836
# Epoch 198/500
#  - 2s - loss: 0.9810 - val_loss: 0.9876
# Epoch 199/500
#  - 2s - loss: 0.9808 - val_loss: 0.9897
# Epoch 200/500
#  - 2s - loss: 0.9823 - val_loss: 0.9888
# Epoch 201/500
#  - 2s - loss: 0.9832 - val_loss: 0.9874
# Epoch 202/500
#  - 2s - loss: 0.9829 - val_loss: 0.9906
# Epoch 203/500
#  - 2s - loss: 0.9819 - val_loss: 0.9889
# Epoch 204/500
#  - 2s - loss: 0.9820 - val_loss: 0.9898
# Epoch 205/500
#  - 2s - loss: 0.9805 - val_loss: 0.9872
# Epoch 206/500
#  - 2s - loss: 0.9821 - val_loss: 0.9882
# Epoch 207/500
#  - 2s - loss: 0.9802 - val_loss: 0.9875
# Epoch 208/500
#  - 2s - loss: 0.9820 - val_loss: 0.9914
# Epoch 209/500
#  - 2s - loss: 0.9808 - val_loss: 0.9883
# Epoch 210/500
#  - 2s - loss: 0.9813 - val_loss: 0.9876
# Epoch 211/500
#  - 2s - loss: 0.9795 - val_loss: 0.9858
# Epoch 212/500
#  - 2s - loss: 0.9803 - val_loss: 0.9870
# Epoch 213/500
#  - 2s - loss: 0.9797 - val_loss: 0.9850
# Epoch 214/500
#  - 2s - loss: 0.9794 - val_loss: 0.9846
# Epoch 215/500
#  - 2s - loss: 0.9805 - val_loss: 0.9877
# Epoch 216/500
#  - 2s - loss: 0.9787 - val_loss: 0.9846
# Epoch 217/500
#  - 2s - loss: 0.9808 - val_loss: 0.9826
# Epoch 218/500
#  - 2s - loss: 0.9799 - val_loss: 0.9855
# Epoch 219/500
#  - 2s - loss: 0.9809 - val_loss: 0.9884
# Epoch 220/500
#  - 2s - loss: 0.9806 - val_loss: 0.9889
# Epoch 221/500
#  - 2s - loss: 0.9810 - val_loss: 0.9882
# Epoch 222/500
#  - 2s - loss: 0.9804 - val_loss: 0.9848
# Epoch 223/500
#  - 2s - loss: 0.9797 - val_loss: 0.9859
# Epoch 224/500
#  - 2s - loss: 0.9806 - val_loss: 0.9866
# Epoch 225/500
#  - 2s - loss: 0.9796 - val_loss: 0.9892
# Epoch 226/500
#  - 2s - loss: 0.9803 - val_loss: 0.9869
# Epoch 227/500
#  - 2s - loss: 0.9796 - val_loss: 0.9899
# Epoch 228/500
#  - 2s - loss: 0.9812 - val_loss: 0.9864
# Epoch 229/500
#  - 2s - loss: 0.9801 - val_loss: 0.9880
# Epoch 230/500
#  - 2s - loss: 0.9809 - val_loss: 0.9849
# Epoch 231/500
#  - 2s - loss: 0.9812 - val_loss: 0.9860
# Epoch 232/500
#  - 2s - loss: 0.9815 - val_loss: 0.9880
# Epoch 233/500
#  - 2s - loss: 0.9811 - val_loss: 0.9899
# Epoch 234/500
#  - 2s - loss: 0.9807 - val_loss: 0.9890
# Epoch 235/500
#  - 2s - loss: 0.9820 - val_loss: 0.9869
# Epoch 236/500
#  - 2s - loss: 0.9817 - val_loss: 0.9907
# Epoch 237/500
#  - 2s - loss: 0.9830 - val_loss: 0.9922
# Epoch 238/500
#  - 2s - loss: 0.9835 - val_loss: 0.9903
# Epoch 239/500
#  - 2s - loss: 0.9820 - val_loss: 0.9884
# Epoch 240/500
#  - 2s - loss: 0.9822 - val_loss: 0.9877
# Epoch 241/500
#  - 2s - loss: 0.9825 - val_loss: 0.9904
# Epoch 242/500
#  - 2s - loss: 0.9825 - val_loss: 0.9899
# Epoch 243/500
#  - 2s - loss: 0.9828 - val_loss: 0.9847
# Epoch 244/500
#  - 2s - loss: 0.9811 - val_loss: 0.9906
# Epoch 245/500
#  - 2s - loss: 0.9834 - val_loss: 0.9896
# Epoch 246/500
#  - 2s - loss: 0.9825 - val_loss: 0.9902
# Epoch 247/500
#  - 2s - loss: 0.9821 - val_loss: 0.9892
# Epoch 248/500
#  - 2s - loss: 0.9809 - val_loss: 0.9867
# Epoch 249/500
#  - 2s - loss: 0.9817 - val_loss: 0.9912
# Epoch 250/500
#  - 2s - loss: 0.9833 - val_loss: 0.9909
# Epoch 251/500
#  - 2s - loss: 0.9828 - val_loss: 0.9909
# Epoch 252/500
#  - 2s - loss: 0.9827 - val_loss: 0.9888
# Epoch 253/500
#  - 2s - loss: 0.9828 - val_loss: 0.9912
# Epoch 254/500
#  - 2s - loss: 0.9820 - val_loss: 0.9882
# Epoch 255/500
#  - 2s - loss: 0.9817 - val_loss: 0.9872
# Epoch 256/500
#  - 2s - loss: 0.9816 - val_loss: 0.9906
# Epoch 257/500
#  - 2s - loss: 0.9837 - val_loss: 0.9901
# Epoch 258/500
#  - 2s - loss: 0.9831 - val_loss: 0.9910
# Epoch 259/500
#  - 2s - loss: 0.9836 - val_loss: 0.9918
# Epoch 260/500
#  - 2s - loss: 0.9829 - val_loss: 0.9927
# Epoch 261/500
#  - 2s - loss: 0.9824 - val_loss: 0.9900
# Epoch 262/500
#  - 2s - loss: 0.9827 - val_loss: 0.9887
# Epoch 263/500
#  - 2s - loss: 0.9843 - val_loss: 0.9904
# Epoch 264/500
#  - 2s - loss: 0.9832 - val_loss: 0.9906
# Epoch 265/500
#  - 2s - loss: 0.9835 - val_loss: 0.9909
# Epoch 266/500
#  - 2s - loss: 0.9827 - val_loss: 0.9923
# Epoch 267/500
#  - 2s - loss: 0.9833 - val_loss: 0.9901
# Epoch 268/500
#  - 2s - loss: 0.9833 - val_loss: 0.9881
# Epoch 269/500
#  - 2s - loss: 0.9826 - val_loss: 0.9909
# Epoch 270/500
#  - 2s - loss: 0.9822 - val_loss: 0.9883
# Epoch 271/500
#  - 2s - loss: 0.9829 - val_loss: 0.9897
# Epoch 272/500
#  - 2s - loss: 0.9829 - val_loss: 0.9930
# Epoch 273/500
#  - 2s - loss: 0.9827 - val_loss: 0.9906
# Epoch 274/500
#  - 2s - loss: 0.9826 - val_loss: 0.9923
# Epoch 275/500
#  - 2s - loss: 0.9854 - val_loss: 0.9931
# Epoch 276/500
#  - 2s - loss: 0.9844 - val_loss: 0.9952
# Epoch 277/500
#  - 2s - loss: 0.9843 - val_loss: 0.9914
# Epoch 278/500
#  - 2s - loss: 0.9837 - val_loss: 0.9939
# Epoch 279/500
#  - 2s - loss: 0.9839 - val_loss: 0.9896
# Epoch 280/500
#  - 2s - loss: 0.9847 - val_loss: 0.9911
# Epoch 281/500
#  - 2s - loss: 0.9849 - val_loss: 0.9924
# Epoch 282/500
#  - 2s - loss: 0.9831 - val_loss: 0.9933
# Epoch 283/500
#  - 2s - loss: 0.9840 - val_loss: 0.9917
# Epoch 284/500
#  - 2s - loss: 0.9831 - val_loss: 0.9904
# Epoch 285/500
#  - 2s - loss: 0.9835 - val_loss: 0.9926
# Epoch 286/500
#  - 2s - loss: 0.9829 - val_loss: 0.9888
# Epoch 287/500
#  - 2s - loss: 0.9814 - val_loss: 0.9877
# Epoch 288/500
#  - 2s - loss: 0.9818 - val_loss: 0.9872
# Epoch 289/500
#  - 2s - loss: 0.9835 - val_loss: 0.9870
# Epoch 290/500
#  - 2s - loss: 0.9809 - val_loss: 0.9874
# Epoch 291/500
#  - 2s - loss: 0.9824 - val_loss: 0.9912
# Epoch 292/500
#  - 2s - loss: 0.9823 - val_loss: 0.9908
# Epoch 293/500
#  - 2s - loss: 0.9807 - val_loss: 0.9873
# Epoch 294/500
#  - 2s - loss: 0.9813 - val_loss: 0.9913
# Epoch 295/500
#  - 2s - loss: 0.9834 - val_loss: 0.9942
# Epoch 296/500
#  - 2s - loss: 0.9815 - val_loss: 0.9895
# Epoch 297/500
#  - 2s - loss: 0.9822 - val_loss: 0.9867
# Epoch 298/500
#  - 2s - loss: 0.9813 - val_loss: 0.9855
# Epoch 299/500
#  - 2s - loss: 0.9804 - val_loss: 0.9837
# Epoch 300/500
#  - 2s - loss: 0.9813 - val_loss: 0.9868
# Epoch 301/500
#  - 2s - loss: 0.9815 - val_loss: 0.9877
# Epoch 302/500
#  - 2s - loss: 0.9813 - val_loss: 0.9871
# Epoch 303/500
#  - 2s - loss: 0.9816 - val_loss: 0.9906
# Epoch 304/500
#  - 2s - loss: 0.9823 - val_loss: 0.9895
# Epoch 305/500
#  - 2s - loss: 0.9822 - val_loss: 0.9899
# Epoch 306/500
#  - 2s - loss: 0.9825 - val_loss: 0.9899
# Epoch 307/500
#  - 2s - loss: 0.9819 - val_loss: 0.9886
# Epoch 308/500
#  - 2s - loss: 0.9824 - val_loss: 0.9886
# Epoch 309/500
#  - 2s - loss: 0.9829 - val_loss: 0.9938
# Epoch 310/500
#  - 2s - loss: 0.9831 - val_loss: 0.9914
# Epoch 311/500
#  - 2s - loss: 0.9832 - val_loss: 0.9895
# Epoch 312/500
#  - 2s - loss: 0.9838 - val_loss: 0.9876
# Epoch 313/500
#  - 2s - loss: 0.9821 - val_loss: 0.9883
# Epoch 314/500
#  - 2s - loss: 0.9819 - val_loss: 0.9892
# Epoch 315/500
#  - 2s - loss: 0.9817 - val_loss: 0.9886
# Epoch 316/500
#  - 2s - loss: 0.9804 - val_loss: 0.9842
# Epoch 317/500
#  - 2s - loss: 0.9794 - val_loss: 0.9852
# Epoch 318/500
#  - 2s - loss: 0.9805 - val_loss: 0.9870
# Epoch 319/500
#  - 2s - loss: 0.9801 - val_loss: 0.9820
# Epoch 320/500
#  - 2s - loss: 0.9794 - val_loss: 0.9834
# Epoch 321/500
#  - 2s - loss: 0.9806 - val_loss: 0.9855
# Epoch 322/500
#  - 2s - loss: 0.9799 - val_loss: 0.9883
# Epoch 323/500
#  - 2s - loss: 0.9828 - val_loss: 0.9889
# Epoch 324/500
#  - 2s - loss: 0.9806 - val_loss: 0.9857
# Epoch 325/500
#  - 2s - loss: 0.9813 - val_loss: 0.9892
# Epoch 326/500
#  - 2s - loss: 0.9808 - val_loss: 0.9848
# Epoch 327/500
#  - 2s - loss: 0.9804 - val_loss: 0.9877
# Epoch 328/500
#  - 2s - loss: 0.9812 - val_loss: 0.9848
# Epoch 329/500
#  - 2s - loss: 0.9815 - val_loss: 0.9861
# Epoch 330/500
#  - 2s - loss: 0.9807 - val_loss: 0.9848
# Epoch 331/500
#  - 2s - loss: 0.9799 - val_loss: 0.9870
# Epoch 332/500
#  - 2s - loss: 0.9819 - val_loss: 0.9882
# Epoch 333/500
#  - 2s - loss: 0.9811 - val_loss: 0.9869
# Epoch 334/500
#  - 2s - loss: 0.9820 - val_loss: 0.9860
# Epoch 335/500
#  - 2s - loss: 0.9806 - val_loss: 0.9854
# Epoch 336/500
#  - 2s - loss: 0.9806 - val_loss: 0.9852
# Epoch 337/500
#  - 2s - loss: 0.9800 - val_loss: 0.9843
# Epoch 338/500
#  - 2s - loss: 0.9808 - val_loss: 0.9859
# Epoch 339/500
#  - 2s - loss: 0.9811 - val_loss: 0.9840
# Epoch 340/500
#  - 2s - loss: 0.9818 - val_loss: 0.9854
# Epoch 341/500
#  - 2s - loss: 0.9810 - val_loss: 0.9852
# Epoch 342/500
#  - 2s - loss: 0.9812 - val_loss: 0.9858
# Epoch 343/500
#  - 2s - loss: 0.9816 - val_loss: 0.9842
# Epoch 344/500
#  - 2s - loss: 0.9801 - val_loss: 0.9834
# Epoch 345/500
#  - 2s - loss: 0.9809 - val_loss: 0.9827
# Epoch 346/500
#  - 2s - loss: 0.9807 - val_loss: 0.9858
# Epoch 347/500
#  - 2s - loss: 0.9807 - val_loss: 0.9882
# Epoch 348/500
#  - 2s - loss: 0.9801 - val_loss: 0.9867
# Epoch 349/500
#  - 2s - loss: 0.9809 - val_loss: 0.9827
# Epoch 350/500
#  - 2s - loss: 0.9817 - val_loss: 0.9905
# Epoch 351/500
#  - 2s - loss: 0.9803 - val_loss: 0.9874
# Epoch 352/500
#  - 2s - loss: 0.9809 - val_loss: 0.9835
# Epoch 353/500
#  - 2s - loss: 0.9796 - val_loss: 0.9820
# Epoch 354/500
#  - 2s - loss: 0.9802 - val_loss: 0.9829
# Epoch 355/500
#  - 2s - loss: 0.9796 - val_loss: 0.9865
# Epoch 356/500
#  - 2s - loss: 0.9816 - val_loss: 0.9834
# Epoch 357/500
#  - 2s - loss: 0.9806 - val_loss: 0.9831
# Epoch 358/500
#  - 2s - loss: 0.9805 - val_loss: 0.9875
# Epoch 359/500
#  - 3s - loss: 0.9804 - val_loss: 0.9860
# Epoch 360/500
#  - 2s - loss: 0.9811 - val_loss: 0.9863
# Epoch 361/500
#  - 2s - loss: 0.9816 - val_loss: 0.9916
# Epoch 362/500
#  - 2s - loss: 0.9820 - val_loss: 0.9870
# Epoch 363/500
#  - 2s - loss: 0.9819 - val_loss: 0.9878
# Epoch 364/500
#  - 2s - loss: 0.9812 - val_loss: 0.9862
# Epoch 365/500
#  - 2s - loss: 0.9815 - val_loss: 0.9848
# Epoch 366/500
#  - 2s - loss: 0.9805 - val_loss: 0.9871
# Epoch 367/500
#  - 2s - loss: 0.9791 - val_loss: 0.9875
# Epoch 368/500
#  - 2s - loss: 0.9809 - val_loss: 0.9865
# Epoch 369/500
#  - 2s - loss: 0.9813 - val_loss: 0.9856
# Epoch 370/500
#  - 2s - loss: 0.9794 - val_loss: 0.9869
# Epoch 371/500
#  - 2s - loss: 0.9816 - val_loss: 0.9910
# Epoch 372/500
#  - 2s - loss: 0.9821 - val_loss: 0.9865
# Epoch 373/500
#  - 2s - loss: 0.9809 - val_loss: 0.9890
# Epoch 374/500
#  - 2s - loss: 0.9796 - val_loss: 0.9887
# Epoch 375/500
#  - 2s - loss: 0.9801 - val_loss: 0.9876
# Epoch 376/500
#  - 2s - loss: 0.9797 - val_loss: 0.9883
# Epoch 377/500
#  - 2s - loss: 0.9807 - val_loss: 0.9858
# Epoch 378/500
#  - 2s - loss: 0.9809 - val_loss: 0.9868
# Epoch 379/500
#  - 2s - loss: 0.9807 - val_loss: 0.9866
# Epoch 380/500
#  - 2s - loss: 0.9801 - val_loss: 0.9891
# Epoch 381/500
#  - 2s - loss: 0.9807 - val_loss: 0.9863
# Epoch 382/500
#  - 2s - loss: 0.9793 - val_loss: 0.9831
# Epoch 383/500
#  - 2s - loss: 0.9789 - val_loss: 0.9873
# Epoch 384/500
#  - 2s - loss: 0.9803 - val_loss: 0.9824
# Epoch 385/500
#  - 2s - loss: 0.9820 - val_loss: 0.9870
# Epoch 386/500
#  - 2s - loss: 0.9817 - val_loss: 0.9869
# Epoch 387/500
#  - 2s - loss: 0.9802 - val_loss: 0.9850
# Epoch 388/500
#  - 2s - loss: 0.9794 - val_loss: 0.9848
# Epoch 389/500
#  - 2s - loss: 0.9786 - val_loss: 0.9832
# Epoch 390/500
#  - 2s - loss: 0.9813 - val_loss: 0.9845
# Epoch 391/500
#  - 2s - loss: 0.9798 - val_loss: 0.9851
# Epoch 392/500
#  - 2s - loss: 0.9797 - val_loss: 0.9831
# Epoch 393/500
#  - 2s - loss: 0.9793 - val_loss: 0.9839
# Epoch 394/500
#  - 2s - loss: 0.9795 - val_loss: 0.9858
# Epoch 395/500
#  - 2s - loss: 0.9800 - val_loss: 0.9854
# Epoch 396/500
#  - 2s - loss: 0.9802 - val_loss: 0.9857
# Epoch 397/500
#  - 2s - loss: 0.9799 - val_loss: 0.9838
# Epoch 398/500
#  - 2s - loss: 0.9785 - val_loss: 0.9857
# Epoch 399/500
#  - 2s - loss: 0.9783 - val_loss: 0.9798
# Epoch 400/500
#  - 2s - loss: 0.9797 - val_loss: 0.9838
# Epoch 401/500
#  - 2s - loss: 0.9799 - val_loss: 0.9844
# Epoch 402/500
#  - 2s - loss: 0.9797 - val_loss: 0.9864
# Epoch 403/500
#  - 2s - loss: 0.9806 - val_loss: 0.9830
# Epoch 404/500
#  - 2s - loss: 0.9811 - val_loss: 0.9818
# Epoch 405/500
#  - 2s - loss: 0.9807 - val_loss: 0.9886
# Epoch 406/500
#  - 2s - loss: 0.9807 - val_loss: 0.9846
# Epoch 407/500
#  - 2s - loss: 0.9801 - val_loss: 0.9853
# Epoch 408/500
#  - 2s - loss: 0.9808 - val_loss: 0.9859
# Epoch 409/500
#  - 2s - loss: 0.9783 - val_loss: 0.9804
# Epoch 410/500
#  - 2s - loss: 0.9781 - val_loss: 0.9853
# Epoch 411/500
#  - 2s - loss: 0.9795 - val_loss: 0.9822
# Epoch 412/500
#  - 2s - loss: 0.9807 - val_loss: 0.9850
# Epoch 413/500
#  - 2s - loss: 0.9802 - val_loss: 0.9875
# Epoch 414/500
#  - 2s - loss: 0.9805 - val_loss: 0.9852
# Epoch 415/500
#  - 2s - loss: 0.9805 - val_loss: 0.9912
# Epoch 416/500
#  - 2s - loss: 0.9796 - val_loss: 0.9859
# Epoch 417/500
#  - 2s - loss: 0.9797 - val_loss: 0.9854
# Epoch 418/500
#  - 2s - loss: 0.9806 - val_loss: 0.9882
# Epoch 419/500
#  - 2s - loss: 0.9810 - val_loss: 0.9853
# Epoch 420/500
#  - 2s - loss: 0.9785 - val_loss: 0.9875
# Epoch 421/500
#  - 2s - loss: 0.9797 - val_loss: 0.9852
# Epoch 422/500
#  - 2s - loss: 0.9793 - val_loss: 0.9849
# Epoch 423/500
#  - 2s - loss: 0.9785 - val_loss: 0.9828
# Epoch 424/500
#  - 2s - loss: 0.9799 - val_loss: 0.9858
# Epoch 425/500
#  - 2s - loss: 0.9794 - val_loss: 0.9835
# Epoch 426/500
#  - 2s - loss: 0.9799 - val_loss: 0.9845
# Epoch 427/500
#  - 2s - loss: 0.9799 - val_loss: 0.9842
# Epoch 428/500
#  - 2s - loss: 0.9792 - val_loss: 0.9819
# Epoch 429/500
#  - 2s - loss: 0.9787 - val_loss: 0.9805
# Epoch 430/500
#  - 2s - loss: 0.9806 - val_loss: 0.9841
# Epoch 431/500
#  - 2s - loss: 0.9797 - val_loss: 0.9868
# Epoch 432/500
#  - 2s - loss: 0.9788 - val_loss: 0.9836
# Epoch 433/500
#  - 2s - loss: 0.9805 - val_loss: 0.9860
# Epoch 434/500
#  - 2s - loss: 0.9805 - val_loss: 0.9854
# Epoch 435/500
#  - 2s - loss: 0.9801 - val_loss: 0.9843
# Epoch 436/500
#  - 2s - loss: 0.9802 - val_loss: 0.9836
# Epoch 437/500
#  - 2s - loss: 0.9804 - val_loss: 0.9848
# Epoch 438/500
#  - 2s - loss: 0.9806 - val_loss: 0.9893
# Epoch 439/500
#  - 2s - loss: 0.9791 - val_loss: 0.9847
# Epoch 440/500
#  - 2s - loss: 0.9792 - val_loss: 0.9833
# Epoch 441/500
#  - 2s - loss: 0.9795 - val_loss: 0.9847
# Epoch 442/500
#  - 2s - loss: 0.9806 - val_loss: 0.9840
# Epoch 443/500
#  - 2s - loss: 0.9801 - val_loss: 0.9811
# Epoch 444/500
#  - 2s - loss: 0.9799 - val_loss: 0.9835
# Epoch 445/500
#  - 2s - loss: 0.9798 - val_loss: 0.9838
# Epoch 446/500
#  - 2s - loss: 0.9798 - val_loss: 0.9880
# Epoch 447/500
#  - 2s - loss: 0.9799 - val_loss: 0.9883
# Epoch 448/500
#  - 2s - loss: 0.9800 - val_loss: 0.9845
# Epoch 449/500
#  - 2s - loss: 0.9809 - val_loss: 0.9839
# Epoch 450/500
#  - 2s - loss: 0.9807 - val_loss: 0.9810
# Epoch 451/500
#  - 2s - loss: 0.9800 - val_loss: 0.9862
# Epoch 452/500
#  - 2s - loss: 0.9813 - val_loss: 0.9861
# Epoch 453/500
#  - 2s - loss: 0.9807 - val_loss: 0.9853
# Epoch 454/500
#  - 2s - loss: 0.9804 - val_loss: 0.9876
# Epoch 455/500
#  - 2s - loss: 0.9805 - val_loss: 0.9853
# Epoch 456/500
#  - 2s - loss: 0.9795 - val_loss: 0.9888
# Epoch 457/500
#  - 2s - loss: 0.9795 - val_loss: 0.9851
# Epoch 458/500
#  - 2s - loss: 0.9803 - val_loss: 0.9876
# Epoch 459/500
#  - 2s - loss: 0.9788 - val_loss: 0.9843
# Epoch 460/500
#  - 2s - loss: 0.9800 - val_loss: 0.9866
# Epoch 461/500
#  - 2s - loss: 0.9801 - val_loss: 0.9835
# Epoch 462/500
#  - 2s - loss: 0.9807 - val_loss: 0.9888
# Epoch 463/500
#  - 2s - loss: 0.9796 - val_loss: 0.9858
# Epoch 464/500
#  - 2s - loss: 0.9799 - val_loss: 0.9846
# Epoch 465/500
#  - 2s - loss: 0.9798 - val_loss: 0.9866
# Epoch 466/500
#  - 2s - loss: 0.9790 - val_loss: 0.9858
# Epoch 467/500
#  - 2s - loss: 0.9789 - val_loss: 0.9889
# Epoch 468/500
#  - 2s - loss: 0.9788 - val_loss: 0.9867
# Epoch 469/500
#  - 2s - loss: 0.9799 - val_loss: 0.9876
# Epoch 470/500
#  - 2s - loss: 0.9789 - val_loss: 0.9855
# Epoch 471/500
#  - 2s - loss: 0.9792 - val_loss: 0.9836
# Epoch 472/500
#  - 2s - loss: 0.9798 - val_loss: 0.9844
# Epoch 473/500
#  - 2s - loss: 0.9786 - val_loss: 0.9836
# Epoch 474/500
#  - 2s - loss: 0.9794 - val_loss: 0.9876
# Epoch 475/500
#  - 2s - loss: 0.9779 - val_loss: 0.9865
# Epoch 476/500
#  - 2s - loss: 0.9796 - val_loss: 0.9853
# Epoch 477/500
#  - 2s - loss: 0.9787 - val_loss: 0.9842
# Epoch 478/500
#  - 2s - loss: 0.9784 - val_loss: 0.9852
# Epoch 479/500
#  - 2s - loss: 0.9797 - val_loss: 0.9852
# Epoch 480/500
#  - 2s - loss: 0.9793 - val_loss: 0.9854
# Epoch 481/500
#  - 2s - loss: 0.9809 - val_loss: 0.9852
# Epoch 482/500
#  - 2s - loss: 0.9790 - val_loss: 0.9854
# Epoch 483/500
#  - 2s - loss: 0.9808 - val_loss: 0.9845
# Epoch 484/500
#  - 2s - loss: 0.9782 - val_loss: 0.9836
# Epoch 485/500
#  - 2s - loss: 0.9786 - val_loss: 0.9852
# Epoch 486/500
#  - 2s - loss: 0.9796 - val_loss: 0.9854
# Epoch 487/500
#  - 2s - loss: 0.9801 - val_loss: 0.9830
# Epoch 488/500
#  - 2s - loss: 0.9806 - val_loss: 0.9820
# Epoch 489/500
#  - 2s - loss: 0.9801 - val_loss: 0.9867
# Epoch 490/500
#  - 2s - loss: 0.9797 - val_loss: 0.9813
# Epoch 491/500
#  - 2s - loss: 0.9804 - val_loss: 0.9829
# Epoch 492/500
#  - 2s - loss: 0.9795 - val_loss: 0.9837
# Epoch 493/500
#  - 2s - loss: 0.9799 - val_loss: 0.9837
# Epoch 494/500
#  - 2s - loss: 0.9803 - val_loss: 0.9836
# Epoch 495/500
#  - 2s - loss: 0.9789 - val_loss: 0.9856
# Epoch 496/500
#  - 2s - loss: 0.9798 - val_loss: 0.9844
# Epoch 497/500
#  - 2s - loss: 0.9790 - val_loss: 0.9858
# Epoch 498/500
#  - 2s - loss: 0.9794 - val_loss: 0.9843
# Epoch 499/500
#  - 2s - loss: 0.9782 - val_loss: 0.9839
# Epoch 500/500
#  - 2s - loss: 0.9803 - val_loss: 0.9842

# %%
plt.figure(figsize=(10, 8))
plt.title("Dense model training", fontsize=12)
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Test")
plt.grid("on")
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("loss", fontsize=12)
plt.legend(loc="upper right")

# %%
def compare_result(y_pred,y_test):
    '''
        compare prediction for test set in different models

    '''
    result = pd.DataFrame([{'Model': k ,
                            'MAE': round(mean_absolute_error(y_pred[k],y_test),2),
                            'RMSE' :  round(sqrt(mean_squared_error(y_pred[k],y_test)),2)} 
                            for k in y_pred.keys()
                          ])
    return result[['Model','MAE','RMSE']].set_index('Model').sort_values('MAE',ascending =False)

# %% [markdown]
# ## Linear Model

# %%
results = sm.OLS((np.array(pd.DataFrame(y_train)[0])) , pd.DataFrame(X_train,columns=inputs)).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     178.9
# Date:                Wed, 19 Dec 2018   Prob (F-statistic):               0.00
# Time:                        23:21:49   Log-Likelihood:                -93684.
# No. Observations:               67670   AIC:                         1.874e+05
# Df Residuals:                   67643   BIC:                         1.877e+05
# Df Model:                          27
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Share_out          -0.0091      0.007     -1.281      0.200      -0.023       0.005
# Mkt_cap             0.0007      0.007      0.098      0.922      -0.013       0.014
# Open               -1.0745      0.200     -5.383      0.000      -1.466      -0.683
# Low                -0.6279      0.225     -2.795      0.005      -1.068      -0.188
# High               -2.2417      0.204    -10.988      0.000      -2.642      -1.842
# Last                7.4888      0.216     34.646      0.000       7.065       7.912
# Close              -3.5446      0.144    -24.661      0.000      -3.826      -3.263
# Volume              0.2974      0.222      1.341      0.180      -0.137       0.732
# Ind_buy_count      -0.0296      0.005     -6.410      0.000      -0.039      -0.021
# Ins_buy_count       0.0477      0.006      8.390      0.000       0.037       0.059
# Ind_sell_count      0.0612      0.009      6.738      0.000       0.043       0.079
# Ins_sell_count     -0.0216      0.006     -3.684      0.000      -0.033      -0.010
# Ind_buy_volume   2134.7240   2551.846      0.837      0.403   -2866.891    7136.339
# Ins_buy_volume   1138.6946   1361.182      0.837      0.403   -1529.220    3806.609
# Ind_sell_volume -1840.4393   2199.819     -0.837      0.403   -6152.082    2471.204
# Ins_sell_volume -1438.0436   1718.842     -0.837      0.403   -4806.973    1930.886
# Ind_buy_value   -4888.0975   6000.791     -0.815      0.415   -1.66e+04    6873.447
# Ins_buy_value   -3505.5060   4303.439     -0.815      0.415   -1.19e+04    4929.231
# Ind_sell_value   4185.8079   5138.686      0.815      0.415   -5886.012    1.43e+04
# Ins_sell_value   4144.4249   5087.801      0.815      0.415   -5827.659    1.41e+04
# Ret_P1              0.1584      0.005     32.575      0.000       0.149       0.168
# Ret_P3             -0.0102      0.007     -1.463      0.143      -0.024       0.003
# Ret_P5              0.0030      0.007      0.404      0.686      -0.012       0.018
# Ret_P10             0.0161      0.007      2.351      0.019       0.003       0.030
# Ret_P20             0.0102      0.008      1.275      0.202      -0.005       0.026
# Ret_P30            -0.0049      0.008     -0.577      0.564      -0.021       0.012
# Ret_P50            -0.0065      0.006     -1.083      0.279      -0.018       0.005
# ==============================================================================
# Omnibus:                    40891.494   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8124079.867
# Skew:                           1.839   Prob(JB):                         0.00
# Kurtosis:                      56.552   Cond. No.                     9.00e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  9e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Analysis

# %%
df[df['f'] == 121][10:17].keys()
# Out:
# Index([u'd', u'f', u'Share_out', u'Mkt_cap', u'Open', u'Low', u'High', u'Last',
#        u'Close', u'Volume', u'Ind_buy_count', u'Ins_buy_count',
#        u'Ind_sell_count', u'Ins_sell_count', u'Ind_buy_volume',
#        u'Ins_buy_volume', u'Ind_sell_volume', u'Ins_sell_volume',
#        u'Ind_buy_value', u'Ins_buy_value', u'Ind_sell_value',
#        u'Ins_sell_value', u'Ret_P1', u'Ret_P3', u'Ret_P5', u'Ret_P10',
#        u'Ret_P20', u'Ret_P30', u'Ret_P50', u'Ret_F1', u'Ret_F3', u'Ret_F5',
#        u'Ret_F10', u'Ret_F20', u'Ret_F30', u'Ret_F50'],
#       dtype='object')

# %%
inputs  = keys[10:18]
outputs = ['Ret_F1','Ret_F3']

fig, axes = plt.subplots(nrows=len(inputs), ncols=2, figsize=(30, 50))
for i,nameo in enumerate(outputs):
    for j,name in enumerate(inputs):
        ax = df.applymap(lambda x: np.log(np.abs(x))).plot.scatter( name,nameo,
                             ax = axes[j][i])
        ax.set(xlabel= name, ylabel=['F1','F2'][i])
plt.tight_layout()
plt.show()
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
df[]
