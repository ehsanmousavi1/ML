# %% [markdown]
# # Introduction
# The Direxion Daily S&P Oil & Gas Exp. & Prod. Bull and Bear 3X Shares (GUSH) seek daily investment results, before fees and expenses, of 300%, or 300% of the inverse (or opposite), of the performance of the S&P Oil & Gas Exploration & Production Select Industry Index. There is no guarantee the funds will meet their stated investment objectives.
# The goal of this project is providing a model to predicit intra-daye return of GUSH according to the the histical data of Gush and also crude oil price.

# %% [markdown]
# ## Comparing Results
#
# I am compring differnt prediction models based on mean of absoulote error (MAE) and mean of square error over (MSE) the test set. The best model is random forest.

# %%
compare_result(y_pred,y_test)
# Out:
#                   MAE    RMSE
# Model
# DNN            0.7589  1.1006
# knn            0.5968  0.9219
# Random Forest  0.5849  0.9216
# Lasso          0.5837  0.9139
# Crude Avrage   0.5726  0.9072

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.cross_validation import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression,Lasso
from sklearn import neighbors
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
get_ipython().magic('matplotlib inline')

# %%
# read Date

director = '/Users/z002df6/Downloads/'
file_name_gush = 'gush.csv'
file_name_oil = 'oil.csv'


df_gush = pd.read_csv(director+file_name_gush)
df_oil  = pd.read_csv(director+file_name_oil)
f = lambda x: ''.join([k for k in x if k != ' '])+'_gush'
df_gush =  df_gush.rename(f, axis='columns')
for l in range(1,5):
    df_gush['lag'+str(l)+'_gush'] = list(df_gush['Close_gush'])[l:]+[np.nan]*l

f = lambda x: ''.join([k for k in x if k != ' '])+'_oil'
df_oil  =  df_oil.rename(f, axis='columns')
df_oil['intra_r'] = (df_oil['Close_oil']-df_oil['Open_oil'])/df_oil['Open_oil']

df_gush['max_r'] = (df_gush['High_gush']-df_gush['Open_gush'])/df_gush['Open_gush']
df_gush['min_r'] = abs(df_gush['Low_gush']-df_gush['Open_gush'])/df_gush['Open_gush']
o = np.array(df_gush['Open_gush'][:-1])
c = np.array(df_gush['Close_gush'][1:])
df_gush['daily_r'] = list((o-c)/c)+[0]

h= pd.DataFrame((list(df_gush['max_r'])+list(-df_gush['min_r'])))

df = pd.concat([df_gush[:-1].reset_index(drop=True),
                df_oil[1:].reset_index(drop=True)],
                axis=1)

df.dropna(inplace=True,how= 'any', axis = 0)
df.to_csv('/Users/z002df6/Downloads/'+'gush_data.csv')
y_pred={}

# %%
#plt.plot(range(70,100),np.percentile(np.array(df_gush['min_r']),range(70,100)))
#fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(30, 10))
df[['max_r','min_r','daily_r']].hist(bins=20, figsize=(10, 10))
fig.show()

# %%
outputs = ['max_r','min_r']
inputs  = list(set(df.keys())-set(outputs+['Date_gush','Date_oil']))

# %%
fig, axes = plt.subplots(nrows=len(inputs), ncols=len(outputs), figsize=(30, 20))
for i,nameo in enumerate(outputs):
    for j,namei in enumerate(inputs):
        ax = df.plot.scatter( namei,nameo,
                             ax = axes[j][i])
        ax.set(xlabel= namei, ylabel=nameo)
plt.tight_layout()
plt.show()

# %%
def CorrMtx(df, dropDuplicates = True):

    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)

    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)

crr = df[inputs+outputs].corr()

CorrMtx(crr, dropDuplicates = True)

# %%
auto_corr ={}
for l in range(1,7):
    for c in ['daily_r','min_r','max_r']:
        auto_corr[c]=auto_corr.get(c,[])+([df[c].autocorr(lag = l)]) 
pd.DataFrame(auto_corr)        
#CorrMtx(pd.DataFrame(auto_corr), dropDuplicates = False  )     
#df['daily_r'].autocorr()
#.apply(lambda x: x.autocorr)
#df['daily_r'].autocorr()
# Out:
#     daily_r     max_r     min_r
# 0 -0.065253  0.069401  0.074611
# 1  0.016216  0.036671  0.068198
# 2  0.001700  0.008474  0.058436
# 3 -0.091122  0.011925  0.074874
# 4  0.030032  0.042652  0.030831
# 5  0.020292  0.116922 -0.039855

# %%
from math import log

X = np.array(df[inputs])
y = np.array(df[outputs].applymap(lambda x: log(x+.00001)))
X,input_normlizer,input_de_normlizer = normalized(X)
y,ON,ODN = normalized(y)
ouput_normlizer    = lambda u : np.log(.00001+ON(u))
ouput_de_normlizer = lambda u :np.exp(ODN(u))-.00001
                                  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
def normalized(X):
    '''
    normilzed array X 
    '''
    avr  = X.mean(axis=0)
    avr  = avr[np.newaxis,:]
    X = X - np.repeat(avr, X.shape[0], axis=0)
    sd   = X.std(axis=0)
    sd  = sd[np.newaxis,:]
    X = X / np.repeat(sd, X.shape[0], axis=0)
    normlizer =lambda u: (u-np.repeat(avr, u.shape[0], axis=0))/np.repeat(sd, u.shape[0], axis=0)
    de_normlizer = lambda u: u*np.repeat(sd, u.shape[0], axis=0)+ np.repeat(avr, u.shape[0], axis=0)
    return X,normlizer, de_normlizer

# %%
pd.DataFrame(y,columns =outputs).describe().applymap(lambda x: round(x,3))
# Out:
#          max_r    min_r
# count  513.000  513.000
# mean     0.000   -0.000
# std      1.001    1.001
# min     -4.715   -3.873
# 25%     -0.250   -0.142
# 50%      0.202    0.246
# 75%      0.569    0.539
# max      1.406    1.250

# %% [markdown]
# ### Crude Average and Linear Model

# %%
avr = y_train.mean(axis=0)
avr = avr[np.newaxis,:]
y_pred['Crude Avrage'] = np.repeat(avr, y_test.shape[0], axis=0)
LM = Lasso(alpha=0.05)
LM.fit(X_train, y_train)
y_pred['Lasso'] = LM.predict(X_test)

# %% [markdown]
# ### Random Forest and K-Nearest Neighbour

# %%
rf = RandomForestRegressor(n_estimators = 100, max_depth = 3)
# Train the model on training data
rf.fit(X_train, y_train)
y_pred['Random Forest'] = rf.predict(X_test)

# %%
knn = neighbors.KNeighborsRegressor(70, weights='distance')
knn.fit(X_train, y_train)
y_pred['knn'] = knn.predict(X_test)

# %% [markdown]
# ### Deep Neural Net

# %%
DNN_model = Sequential()
DNN_model.add(Dense(100,input_dim=X_train.shape[1],init='uniform',activation='relu'))
DNN_model.add(Dropout(0.5))
DNN_model.add(Dense(50,init='uniform',activation='tanh'))
DNN_model.add(Dropout(0.5))
DNN_model.add(Dense(y_train.shape[1],init='uniform',activation='linear'))
DNN_model.summary()


# ### Fitting the DNN

mn = X_train.mean(axis=0)
sd = X_train.mean(axis=0)
#model.compile(loss='mean_absolute_error',optimizer='adam',metrics='[accuracy]')
DNN_model.compile(loss='mean_squared_error',optimizer='adam')
history = DNN_model.fit((X_train-mn)/sd,y_train,  
                    validation_data=((X_test-mn)/sd, y_test),
                    epochs =5000,
                    batch_size=100,
                    verbose=2)
y_pred['DNN'] = DNN_model.predict((X_test-mn)/sd)
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, activation="relu", kernel_initializer="uniform", input_dim=16)`
#
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(50, activation="tanh", kernel_initializer="uniform")`
#   after removing the cwd from sys.path.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(2, activation="linear", kernel_initializer="uniform")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 100)               1700
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 6,852
# Trainable params: 6,852
# Non-trainable params: 0
# _________________________________________________________________
# Train on 343 samples, validate on 170 samples
# Epoch 1/5000
#  - 0s - loss: 1.0815 - val_loss: 0.9149
# Epoch 2/5000
#  - 0s - loss: 1.0656 - val_loss: 0.9210
# Epoch 3/5000
#  - 0s - loss: 1.0823 - val_loss: 0.9230
# Epoch 4/5000
#  - 0s - loss: 1.0418 - val_loss: 0.9246
# Epoch 5/5000
#  - 0s - loss: 1.0149 - val_loss: 0.9242
# Epoch 6/5000
#  - 0s - loss: 1.0401 - val_loss: 0.9245
# Epoch 7/5000
#  - 0s - loss: 1.0206 - val_loss: 0.9249
# Epoch 8/5000
#  - 0s - loss: 1.0262 - val_loss: 0.9232
# Epoch 9/5000
#  - 0s - loss: 1.0475 - val_loss: 0.9232
# Epoch 10/5000
#  - 0s - loss: 1.0161 - val_loss: 0.9206
# Epoch 11/5000
#  - 0s - loss: 1.0131 - val_loss: 0.9194
# Epoch 12/5000
#  - 0s - loss: 1.0147 - val_loss: 0.9173
# Epoch 13/5000
#  - 0s - loss: 1.0106 - val_loss: 0.9148
# Epoch 14/5000
#  - 0s - loss: 1.0097 - val_loss: 0.9109
# Epoch 15/5000
#  - 0s - loss: 1.0093 - val_loss: 0.9081
# Epoch 16/5000
#  - 0s - loss: 1.0117 - val_loss: 0.9068
# Epoch 17/5000
#  - 0s - loss: 0.9889 - val_loss: 0.9071
# Epoch 18/5000
#  - 0s - loss: 0.9904 - val_loss: 0.9070
# Epoch 19/5000
#  - 0s - loss: 1.0113 - val_loss: 0.9052
# Epoch 20/5000
#  - 0s - loss: 0.9916 - val_loss: 0.9015
# Epoch 21/5000
#  - 0s - loss: 0.9999 - val_loss: 0.8971
# Epoch 22/5000
#  - 0s - loss: 1.0046 - val_loss: 0.8979
# Epoch 23/5000
#  - 0s - loss: 0.9941 - val_loss: 0.9018
# Epoch 24/5000
#  - 0s - loss: 0.9915 - val_loss: 0.8984
# Epoch 25/5000
#  - 0s - loss: 0.9886 - val_loss: 0.8978
# Epoch 26/5000
#  - 0s - loss: 0.9932 - val_loss: 0.8957
# Epoch 27/5000
#  - 0s - loss: 0.9960 - val_loss: 0.8919
# Epoch 28/5000
#  - 0s - loss: 0.9762 - val_loss: 0.8877
# Epoch 29/5000
#  - 0s - loss: 0.9769 - val_loss: 0.8839
# Epoch 30/5000
#  - 0s - loss: 0.9629 - val_loss: 0.8803
# Epoch 31/5000
#  - 0s - loss: 0.9703 - val_loss: 0.8743
# Epoch 32/5000
#  - 0s - loss: 0.9682 - val_loss: 0.8716
# Epoch 33/5000
#  - 0s - loss: 0.9539 - val_loss: 0.8690
# Epoch 34/5000
#  - 0s - loss: 0.9478 - val_loss: 0.8627
# Epoch 35/5000
#  - 0s - loss: 0.9610 - val_loss: 0.8601
# Epoch 36/5000
#  - 0s - loss: 0.9381 - val_loss: 0.8565
# Epoch 37/5000
#  - 0s - loss: 0.9625 - val_loss: 0.8533
# Epoch 38/5000
#  - 0s - loss: 0.9372 - val_loss: 0.8467
# Epoch 39/5000
#  - 0s - loss: 0.9283 - val_loss: 0.8412
# Epoch 40/5000
#  - 0s - loss: 0.9511 - val_loss: 0.8388
# Epoch 41/5000
#  - 0s - loss: 0.9587 - val_loss: 0.8452
# Epoch 42/5000
#  - 0s - loss: 0.9411 - val_loss: 0.8506
# Epoch 43/5000
#  - 0s - loss: 0.9311 - val_loss: 0.8484
# Epoch 44/5000
#  - 0s - loss: 0.9193 - val_loss: 0.8318
# Epoch 45/5000
#  - 0s - loss: 0.9232 - val_loss: 0.8243
# Epoch 46/5000
#  - 0s - loss: 0.9194 - val_loss: 0.8174
# Epoch 47/5000
#  - 0s - loss: 0.9419 - val_loss: 0.8133
# Epoch 48/5000
#  - 0s - loss: 0.9173 - val_loss: 0.8135
# Epoch 49/5000
#  - 0s - loss: 0.9048 - val_loss: 0.8107
# Epoch 50/5000
#  - 0s - loss: 0.9392 - val_loss: 0.8162
# Epoch 51/5000
#  - 0s - loss: 0.9042 - val_loss: 0.8140
# Epoch 52/5000
#  - 0s - loss: 0.8822 - val_loss: 0.8032
# Epoch 53/5000
#  - 0s - loss: 0.9067 - val_loss: 0.7968
# Epoch 54/5000
#  - 0s - loss: 0.8721 - val_loss: 0.7941
# Epoch 55/5000
#  - 0s - loss: 0.8723 - val_loss: 0.7880
# Epoch 56/5000
#  - 0s - loss: 0.9191 - val_loss: 0.7862
# Epoch 57/5000
#  - 0s - loss: 0.8831 - val_loss: 0.7812
# Epoch 58/5000
#  - 0s - loss: 0.8600 - val_loss: 0.7682
# Epoch 59/5000
#  - 0s - loss: 0.8856 - val_loss: 0.7628
# Epoch 60/5000
#  - 0s - loss: 0.8651 - val_loss: 0.7634
# Epoch 61/5000
#  - 0s - loss: 0.8441 - val_loss: 0.7600
# Epoch 62/5000
#  - 0s - loss: 0.8640 - val_loss: 0.7527
# Epoch 63/5000
#  - 0s - loss: 0.8699 - val_loss: 0.7416
# Epoch 64/5000
#  - 0s - loss: 0.8556 - val_loss: 0.7415
# Epoch 65/5000
#  - 0s - loss: 0.8369 - val_loss: 0.7512
# Epoch 66/5000
#  - 0s - loss: 0.8128 - val_loss: 0.7472
# Epoch 67/5000
#  - 0s - loss: 0.8184 - val_loss: 0.7388
# Epoch 68/5000
#  - 0s - loss: 0.8479 - val_loss: 0.7391
# Epoch 69/5000
#  - 0s - loss: 0.8123 - val_loss: 0.7471
# Epoch 70/5000
#  - 0s - loss: 0.8029 - val_loss: 0.7548
# Epoch 71/5000
#  - 0s - loss: 0.8135 - val_loss: 0.7546
# Epoch 72/5000
#  - 0s - loss: 0.8227 - val_loss: 0.7458
# Epoch 73/5000
#  - 0s - loss: 0.7914 - val_loss: 0.7379
# Epoch 74/5000
#  - 0s - loss: 0.7899 - val_loss: 0.7542
# Epoch 75/5000
#  - 0s - loss: 0.7973 - val_loss: 0.7228
# Epoch 76/5000
#  - 0s - loss: 0.7901 - val_loss: 0.7220
# Epoch 77/5000
#  - 0s - loss: 0.7895 - val_loss: 0.7174
# Epoch 78/5000
#  - 0s - loss: 0.7801 - val_loss: 0.7038
# Epoch 79/5000
#  - 0s - loss: 0.7737 - val_loss: 0.7043
# Epoch 80/5000
#  - 0s - loss: 0.7385 - val_loss: 0.7070
# Epoch 81/5000
#  - 0s - loss: 0.7843 - val_loss: 0.6999
# Epoch 82/5000
#  - 0s - loss: 0.7563 - val_loss: 0.7142
# Epoch 83/5000
#  - 0s - loss: 0.7454 - val_loss: 0.7088
# Epoch 84/5000
#  - 0s - loss: 0.8044 - val_loss: 0.7088
# Epoch 85/5000
#  - 0s - loss: 0.7685 - val_loss: 0.7324
# Epoch 86/5000
#  - 0s - loss: 0.7456 - val_loss: 0.6995
# Epoch 87/5000
#  - 0s - loss: 0.7522 - val_loss: 0.6932
# Epoch 88/5000
#  - 0s - loss: 0.7190 - val_loss: 0.7113
# Epoch 89/5000
#  - 0s - loss: 0.7384 - val_loss: 0.6988
# Epoch 90/5000
#  - 0s - loss: 0.7183 - val_loss: 0.7041
# Epoch 91/5000
#  - 0s - loss: 0.7422 - val_loss: 0.6755
# Epoch 92/5000
#  - 0s - loss: 0.7408 - val_loss: 0.6797
# Epoch 93/5000
#  - 0s - loss: 0.7244 - val_loss: 0.6729
# Epoch 94/5000
#  - 0s - loss: 0.7203 - val_loss: 0.6946
# Epoch 95/5000
#  - 0s - loss: 0.7128 - val_loss: 0.6952
# Epoch 96/5000
#  - 0s - loss: 0.7424 - val_loss: 0.6817
# Epoch 97/5000
#  - 0s - loss: 0.7046 - val_loss: 0.6954
# Epoch 98/5000
#  - 0s - loss: 0.7395 - val_loss: 0.6706
# Epoch 99/5000
#  - 0s - loss: 0.7202 - val_loss: 0.6640
# Epoch 100/5000
#  - 0s - loss: 0.6988 - val_loss: 0.6616
# Epoch 101/5000
#  - 0s - loss: 0.7313 - val_loss: 0.6406
# Epoch 102/5000
#  - 0s - loss: 0.7385 - val_loss: 0.6408
# Epoch 103/5000
#  - 0s - loss: 0.6902 - val_loss: 0.6476
# Epoch 104/5000
#  - 0s - loss: 0.6919 - val_loss: 0.6561
# Epoch 105/5000
#  - 0s - loss: 0.6802 - val_loss: 0.6720
# Epoch 106/5000
#  - 0s - loss: 0.6605 - val_loss: 0.6823
# Epoch 107/5000
#  - 0s - loss: 0.7222 - val_loss: 0.6676
# Epoch 108/5000
#  - 0s - loss: 0.6676 - val_loss: 0.6531
# Epoch 109/5000
#  - 0s - loss: 0.6931 - val_loss: 0.6583
# Epoch 110/5000
#  - 0s - loss: 0.6882 - val_loss: 0.6465
# Epoch 111/5000
#  - 0s - loss: 0.6908 - val_loss: 0.6461
# Epoch 112/5000
#  - 0s - loss: 0.6763 - val_loss: 0.6456
# Epoch 113/5000
#  - 0s - loss: 0.6859 - val_loss: 0.6402
# Epoch 114/5000
#  - 0s - loss: 0.6554 - val_loss: 0.6398
# Epoch 115/5000
#  - 0s - loss: 0.6981 - val_loss: 0.6446
# Epoch 116/5000
#  - 0s - loss: 0.6466 - val_loss: 0.6558
# Epoch 117/5000
#  - 0s - loss: 0.6778 - val_loss: 0.6468
# Epoch 118/5000
#  - 0s - loss: 0.6887 - val_loss: 0.6539
# Epoch 119/5000
#  - 0s - loss: 0.6648 - val_loss: 0.6758
# Epoch 120/5000
#  - 0s - loss: 0.6613 - val_loss: 0.6638
# Epoch 121/5000
#  - 0s - loss: 0.6486 - val_loss: 0.6483
# Epoch 122/5000
#  - 0s - loss: 0.6713 - val_loss: 0.6353
# Epoch 123/5000
#  - 0s - loss: 0.6542 - val_loss: 0.6519
# Epoch 124/5000
#  - 0s - loss: 0.6784 - val_loss: 0.6341
# Epoch 125/5000
#  - 0s - loss: 0.6723 - val_loss: 0.6273
# Epoch 126/5000
#  - 0s - loss: 0.6630 - val_loss: 0.6301
# Epoch 127/5000
#  - 0s - loss: 0.6533 - val_loss: 0.6479
# Epoch 128/5000
#  - 0s - loss: 0.6860 - val_loss: 0.6344
# Epoch 129/5000
#  - 0s - loss: 0.6567 - val_loss: 0.6309
# Epoch 130/5000
#  - 0s - loss: 0.6237 - val_loss: 0.6281
# Epoch 131/5000
#  - 0s - loss: 0.6617 - val_loss: 0.6342
# Epoch 132/5000
#  - 0s - loss: 0.6941 - val_loss: 0.6303
# Epoch 133/5000
#  - 0s - loss: 0.6600 - val_loss: 0.6497
# Epoch 134/5000
#  - 0s - loss: 0.6515 - val_loss: 0.6405
# Epoch 135/5000
#  - 0s - loss: 0.6477 - val_loss: 0.6367
# Epoch 136/5000
#  - 0s - loss: 0.6542 - val_loss: 0.6331
# Epoch 137/5000
#  - 0s - loss: 0.6405 - val_loss: 0.6234
# Epoch 138/5000
#  - 0s - loss: 0.6391 - val_loss: 0.6277
# Epoch 139/5000
#  - 0s - loss: 0.6550 - val_loss: 0.6425
# Epoch 140/5000
#  - 0s - loss: 0.6531 - val_loss: 0.6498
# Epoch 141/5000
#  - 0s - loss: 0.6451 - val_loss: 0.6365
# Epoch 142/5000
#  - 0s - loss: 0.6108 - val_loss: 0.6301
# Epoch 143/5000
#  - 0s - loss: 0.6438 - val_loss: 0.6220
# Epoch 144/5000
#  - 0s - loss: 0.6426 - val_loss: 0.6315
# Epoch 145/5000
#  - 0s - loss: 0.6240 - val_loss: 0.6234
# Epoch 146/5000
#  - 0s - loss: 0.6316 - val_loss: 0.6197
# Epoch 147/5000
#  - 0s - loss: 0.6102 - val_loss: 0.6229
# Epoch 148/5000
#  - 0s - loss: 0.6282 - val_loss: 0.6206
# Epoch 149/5000
#  - 0s - loss: 0.6117 - val_loss: 0.6187
# Epoch 150/5000
#  - 0s - loss: 0.6631 - val_loss: 0.6302
# Epoch 151/5000
#  - 0s - loss: 0.6235 - val_loss: 0.6227
# Epoch 152/5000
#  - 0s - loss: 0.6218 - val_loss: 0.6182
# Epoch 153/5000
#  - 0s - loss: 0.6593 - val_loss: 0.6515
# Epoch 154/5000
#  - 0s - loss: 0.6420 - val_loss: 0.6241
# Epoch 155/5000
#  - 0s - loss: 0.6205 - val_loss: 0.6203
# Epoch 156/5000
#  - 0s - loss: 0.6228 - val_loss: 0.6308
# Epoch 157/5000
#  - 0s - loss: 0.6378 - val_loss: 0.6240
# Epoch 158/5000
#  - 0s - loss: 0.6284 - val_loss: 0.6217
# Epoch 159/5000
#  - 0s - loss: 0.6189 - val_loss: 0.6399
# Epoch 160/5000
#  - 0s - loss: 0.6325 - val_loss: 0.6249
# Epoch 161/5000
#  - 0s - loss: 0.6072 - val_loss: 0.6252
# Epoch 162/5000
#  - 0s - loss: 0.6529 - val_loss: 0.6151
# Epoch 163/5000
#  - 0s - loss: 0.6465 - val_loss: 0.6053
# Epoch 164/5000
#  - 0s - loss: 0.6460 - val_loss: 0.6097
# Epoch 165/5000
#  - 0s - loss: 0.5793 - val_loss: 0.6492
# Epoch 166/5000
#  - 0s - loss: 0.6574 - val_loss: 0.6517
# Epoch 167/5000
#  - 0s - loss: 0.6345 - val_loss: 0.6358
# Epoch 168/5000
#  - 0s - loss: 0.6358 - val_loss: 0.6193
# Epoch 169/5000
#  - 0s - loss: 0.6134 - val_loss: 0.6260
# Epoch 170/5000
#  - 0s - loss: 0.6182 - val_loss: 0.6136
# Epoch 171/5000
#  - 0s - loss: 0.6570 - val_loss: 0.6216
# Epoch 172/5000
#  - 0s - loss: 0.6258 - val_loss: 0.6064
# Epoch 173/5000
#  - 0s - loss: 0.6174 - val_loss: 0.6123
# Epoch 174/5000
#  - 0s - loss: 0.6104 - val_loss: 0.6261
# Epoch 175/5000
#  - 0s - loss: 0.6484 - val_loss: 0.6192
# Epoch 176/5000
#  - 0s - loss: 0.6514 - val_loss: 0.6018
# Epoch 177/5000
#  - 0s - loss: 0.6184 - val_loss: 0.6033
# Epoch 178/5000
#  - 0s - loss: 0.5958 - val_loss: 0.6141
# Epoch 179/5000
#  - 0s - loss: 0.5992 - val_loss: 0.6157
# Epoch 180/5000
#  - 0s - loss: 0.6168 - val_loss: 0.5911
# Epoch 181/5000
#  - 0s - loss: 0.6280 - val_loss: 0.5903
# Epoch 182/5000
#  - 0s - loss: 0.6120 - val_loss: 0.5998
# Epoch 183/5000
#  - 0s - loss: 0.6008 - val_loss: 0.5957
# Epoch 184/5000
#  - 0s - loss: 0.6202 - val_loss: 0.6104
# Epoch 185/5000
#  - 0s - loss: 0.6038 - val_loss: 0.6216
# Epoch 186/5000
#  - 0s - loss: 0.6147 - val_loss: 0.6061
# Epoch 187/5000
#  - 0s - loss: 0.6047 - val_loss: 0.5995
# Epoch 188/5000
#  - 0s - loss: 0.6054 - val_loss: 0.5940
# Epoch 189/5000
#  - 0s - loss: 0.6067 - val_loss: 0.5985
# Epoch 190/5000
#  - 0s - loss: 0.5856 - val_loss: 0.5832
# Epoch 191/5000
#  - 0s - loss: 0.5902 - val_loss: 0.5856
# Epoch 192/5000
#  - 0s - loss: 0.5893 - val_loss: 0.5738
# Epoch 193/5000
#  - 0s - loss: 0.5856 - val_loss: 0.5976
# Epoch 194/5000
#  - 0s - loss: 0.5803 - val_loss: 0.5860
# Epoch 195/5000
#  - 0s - loss: 0.6019 - val_loss: 0.5974
# Epoch 196/5000
#  - 0s - loss: 0.5967 - val_loss: 0.5980
# Epoch 197/5000
#  - 0s - loss: 0.5794 - val_loss: 0.5994
# Epoch 198/5000
#  - 0s - loss: 0.5999 - val_loss: 0.6176
# Epoch 199/5000
#  - 0s - loss: 0.6106 - val_loss: 0.6273
# Epoch 200/5000
#  - 0s - loss: 0.6117 - val_loss: 0.6338
# Epoch 201/5000
#  - 0s - loss: 0.6033 - val_loss: 0.6085
# Epoch 202/5000
#  - 0s - loss: 0.6225 - val_loss: 0.5905
# Epoch 203/5000
#  - 0s - loss: 0.5892 - val_loss: 0.5938
# Epoch 204/5000
#  - 0s - loss: 0.5758 - val_loss: 0.5959
# Epoch 205/5000
#  - 0s - loss: 0.6037 - val_loss: 0.5893
# Epoch 206/5000
#  - 0s - loss: 0.5861 - val_loss: 0.5948
# Epoch 207/5000
#  - 0s - loss: 0.5868 - val_loss: 0.6062
# Epoch 208/5000
#  - 0s - loss: 0.6260 - val_loss: 0.6403
# Epoch 209/5000
#  - 0s - loss: 0.5886 - val_loss: 0.6323
# Epoch 210/5000
#  - 0s - loss: 0.5906 - val_loss: 0.6292
# Epoch 211/5000
#  - 0s - loss: 0.6153 - val_loss: 0.6167
# Epoch 212/5000
#  - 0s - loss: 0.5903 - val_loss: 0.6009
# Epoch 213/5000
#  - 0s - loss: 0.5948 - val_loss: 0.6074
# Epoch 214/5000
#  - 0s - loss: 0.5663 - val_loss: 0.6104
# Epoch 215/5000
#  - 0s - loss: 0.5898 - val_loss: 0.6163
# Epoch 216/5000
#  - 0s - loss: 0.5881 - val_loss: 0.6082
# Epoch 217/5000
#  - 0s - loss: 0.5885 - val_loss: 0.6034
# Epoch 218/5000
#  - 0s - loss: 0.6015 - val_loss: 0.5948
# Epoch 219/5000
#  - 0s - loss: 0.5656 - val_loss: 0.5961
# Epoch 220/5000
#  - 0s - loss: 0.5736 - val_loss: 0.5865
# Epoch 221/5000
#  - 0s - loss: 0.5582 - val_loss: 0.5893
# Epoch 222/5000
#  - 0s - loss: 0.5897 - val_loss: 0.5962
# Epoch 223/5000
#  - 0s - loss: 0.5675 - val_loss: 0.5825
# Epoch 224/5000
#  - 0s - loss: 0.5567 - val_loss: 0.6013
# Epoch 225/5000
#  - 0s - loss: 0.6044 - val_loss: 0.6102
# Epoch 226/5000
#  - 0s - loss: 0.5846 - val_loss: 0.6012
# Epoch 227/5000
#  - 0s - loss: 0.5716 - val_loss: 0.6043
# Epoch 228/5000
#  - 0s - loss: 0.5535 - val_loss: 0.5902
# Epoch 229/5000
#  - 0s - loss: 0.5945 - val_loss: 0.5965
# Epoch 230/5000
#  - 0s - loss: 0.5764 - val_loss: 0.5820
# Epoch 231/5000
#  - 0s - loss: 0.5592 - val_loss: 0.5897
# Epoch 232/5000
#  - 0s - loss: 0.5629 - val_loss: 0.5977
# Epoch 233/5000
#  - 0s - loss: 0.5859 - val_loss: 0.6143
# Epoch 234/5000
#  - 0s - loss: 0.5488 - val_loss: 0.6090
# Epoch 235/5000
#  - 0s - loss: 0.5880 - val_loss: 0.6083
# Epoch 236/5000
#  - 0s - loss: 0.5836 - val_loss: 0.6256
# Epoch 237/5000
#  - 0s - loss: 0.5791 - val_loss: 0.6039
# Epoch 238/5000
#  - 0s - loss: 0.5884 - val_loss: 0.5890
# Epoch 239/5000
#  - 0s - loss: 0.5848 - val_loss: 0.5860
# Epoch 240/5000
#  - 0s - loss: 0.5567 - val_loss: 0.5950
# Epoch 241/5000
#  - 0s - loss: 0.5690 - val_loss: 0.6060
# Epoch 242/5000
#  - 0s - loss: 0.5687 - val_loss: 0.6188
# Epoch 243/5000
#  - 0s - loss: 0.5653 - val_loss: 0.6150
# Epoch 244/5000
#  - 0s - loss: 0.5646 - val_loss: 0.6051
# Epoch 245/5000
#  - 0s - loss: 0.5820 - val_loss: 0.6009
# Epoch 246/5000
#  - 0s - loss: 0.5702 - val_loss: 0.5940
# Epoch 247/5000
#  - 0s - loss: 0.5774 - val_loss: 0.6138
# Epoch 248/5000
#  - 0s - loss: 0.5960 - val_loss: 0.6040
# Epoch 249/5000
#  - 0s - loss: 0.5711 - val_loss: 0.5912
# Epoch 250/5000
#  - 0s - loss: 0.5427 - val_loss: 0.6087
# Epoch 251/5000
#  - 0s - loss: 0.6111 - val_loss: 0.6042
# Epoch 252/5000
#  - 0s - loss: 0.5719 - val_loss: 0.6088
# Epoch 253/5000
#  - 0s - loss: 0.5623 - val_loss: 0.6172
# Epoch 254/5000
#  - 0s - loss: 0.5929 - val_loss: 0.6198
# Epoch 255/5000
#  - 0s - loss: 0.5683 - val_loss: 0.6105
# Epoch 256/5000
#  - 0s - loss: 0.5807 - val_loss: 0.5959
# Epoch 257/5000
#  - 0s - loss: 0.5556 - val_loss: 0.5911
# Epoch 258/5000
#  - 0s - loss: 0.5544 - val_loss: 0.6007
# Epoch 259/5000
#  - 0s - loss: 0.5801 - val_loss: 0.5939
# Epoch 260/5000
#  - 0s - loss: 0.5762 - val_loss: 0.5880
# Epoch 261/5000
#  - 0s - loss: 0.5436 - val_loss: 0.6268
# Epoch 262/5000
#  - 0s - loss: 0.5709 - val_loss: 0.5842
# Epoch 263/5000
#  - 0s - loss: 0.5492 - val_loss: 0.5867
# Epoch 264/5000
#  - 0s - loss: 0.5608 - val_loss: 0.6011
# Epoch 265/5000
#  - 0s - loss: 0.5576 - val_loss: 0.5975
# Epoch 266/5000
#  - 0s - loss: 0.5577 - val_loss: 0.5987
# Epoch 267/5000
#  - 0s - loss: 0.5336 - val_loss: 0.6082
# Epoch 268/5000
#  - 0s - loss: 0.5297 - val_loss: 0.6066
# Epoch 269/5000
#  - 0s - loss: 0.5385 - val_loss: 0.5996
# Epoch 270/5000
#  - 0s - loss: 0.5234 - val_loss: 0.5932
# Epoch 271/5000
#  - 0s - loss: 0.5641 - val_loss: 0.5831
# Epoch 272/5000
#  - 0s - loss: 0.5243 - val_loss: 0.5812
# Epoch 273/5000
#  - 0s - loss: 0.5596 - val_loss: 0.5807
# Epoch 274/5000
#  - 0s - loss: 0.5328 - val_loss: 0.5729
# Epoch 275/5000
#  - 0s - loss: 0.5600 - val_loss: 0.5754
# Epoch 276/5000
#  - 0s - loss: 0.5802 - val_loss: 0.5781
# Epoch 277/5000
#  - 0s - loss: 0.5665 - val_loss: 0.5832
# Epoch 278/5000
#  - 0s - loss: 0.5670 - val_loss: 0.5768
# Epoch 279/5000
#  - 0s - loss: 0.5556 - val_loss: 0.5740
# Epoch 280/5000
#  - 0s - loss: 0.5649 - val_loss: 0.5699
# Epoch 281/5000
#  - 0s - loss: 0.5938 - val_loss: 0.5731
# Epoch 282/5000
#  - 0s - loss: 0.5743 - val_loss: 0.5836
# Epoch 283/5000
#  - 0s - loss: 0.5875 - val_loss: 0.6140
# Epoch 284/5000
#  - 0s - loss: 0.5719 - val_loss: 0.6032
# Epoch 285/5000
#  - 0s - loss: 0.5645 - val_loss: 0.6176
# Epoch 286/5000
#  - 0s - loss: 0.5330 - val_loss: 0.5976
# Epoch 287/5000
#  - 0s - loss: 0.5223 - val_loss: 0.6110
# Epoch 288/5000
#  - 0s - loss: 0.5932 - val_loss: 0.6128
# Epoch 289/5000
#  - 0s - loss: 0.5365 - val_loss: 0.5918
# Epoch 290/5000
#  - 0s - loss: 0.5801 - val_loss: 0.5970
# Epoch 291/5000
#  - 0s - loss: 0.5640 - val_loss: 0.6088
# Epoch 292/5000
#  - 0s - loss: 0.5811 - val_loss: 0.5807
# Epoch 293/5000
#  - 0s - loss: 0.6189 - val_loss: 0.5936
# Epoch 294/5000
#  - 0s - loss: 0.5836 - val_loss: 0.5857
# Epoch 295/5000
#  - 0s - loss: 0.5852 - val_loss: 0.5819
# Epoch 296/5000
#  - 0s - loss: 0.5711 - val_loss: 0.5808
# Epoch 297/5000
#  - 0s - loss: 0.5296 - val_loss: 0.5881
# Epoch 298/5000
#  - 0s - loss: 0.5526 - val_loss: 0.5885
# Epoch 299/5000
#  - 0s - loss: 0.5718 - val_loss: 0.5931
# Epoch 300/5000
#  - 0s - loss: 0.5509 - val_loss: 0.6055
# Epoch 301/5000
#  - 0s - loss: 0.5444 - val_loss: 0.5948
# Epoch 302/5000
#  - 0s - loss: 0.5190 - val_loss: 0.5853
# Epoch 303/5000
#  - 0s - loss: 0.5594 - val_loss: 0.5727
# Epoch 304/5000
#  - 0s - loss: 0.5272 - val_loss: 0.5723
# Epoch 305/5000
#  - 0s - loss: 0.5310 - val_loss: 0.5680
# Epoch 306/5000
#  - 0s - loss: 0.5131 - val_loss: 0.5717
# Epoch 307/5000
#  - 0s - loss: 0.5294 - val_loss: 0.5789
# Epoch 308/5000
#  - 0s - loss: 0.5194 - val_loss: 0.5893
# Epoch 309/5000
#  - 0s - loss: 0.5188 - val_loss: 0.6077
# Epoch 310/5000
#  - 0s - loss: 0.5652 - val_loss: 0.5930
# Epoch 311/5000
#  - 0s - loss: 0.5437 - val_loss: 0.5878
# Epoch 312/5000
#  - 0s - loss: 0.5452 - val_loss: 0.5963
# Epoch 313/5000
#  - 0s - loss: 0.5567 - val_loss: 0.5890
# Epoch 314/5000
#  - 0s - loss: 0.5726 - val_loss: 0.5817
# Epoch 315/5000
#  - 0s - loss: 0.5654 - val_loss: 0.5839
# Epoch 316/5000
#  - 0s - loss: 0.5571 - val_loss: 0.6292
# Epoch 317/5000
#  - 0s - loss: 0.5670 - val_loss: 0.6026
# Epoch 318/5000
#  - 0s - loss: 0.5271 - val_loss: 0.6034
# Epoch 319/5000
#  - 0s - loss: 0.5526 - val_loss: 0.5988
# Epoch 320/5000
#  - 0s - loss: 0.5409 - val_loss: 0.6055
# Epoch 321/5000
#  - 0s - loss: 0.5527 - val_loss: 0.5993
# Epoch 322/5000
#  - 0s - loss: 0.5341 - val_loss: 0.5983
# Epoch 323/5000
#  - 0s - loss: 0.5093 - val_loss: 0.5843
# Epoch 324/5000
#  - 0s - loss: 0.5157 - val_loss: 0.5970
# Epoch 325/5000
#  - 0s - loss: 0.5568 - val_loss: 0.6014
# Epoch 326/5000
#  - 0s - loss: 0.5481 - val_loss: 0.5978
# Epoch 327/5000
#  - 0s - loss: 0.5497 - val_loss: 0.6105
# Epoch 328/5000
#  - 0s - loss: 0.5348 - val_loss: 0.6053
# Epoch 329/5000
#  - 0s - loss: 0.5409 - val_loss: 0.6150
# Epoch 330/5000
#  - 0s - loss: 0.5555 - val_loss: 0.6066
# Epoch 331/5000
#  - 0s - loss: 0.5657 - val_loss: 0.5996
# Epoch 332/5000
#  - 0s - loss: 0.5122 - val_loss: 0.6104
# Epoch 333/5000
#  - 0s - loss: 0.5467 - val_loss: 0.6003
# Epoch 334/5000
#  - 0s - loss: 0.5436 - val_loss: 0.5917
# Epoch 335/5000
#  - 0s - loss: 0.5629 - val_loss: 0.5916
# Epoch 336/5000
#  - 0s - loss: 0.5295 - val_loss: 0.6293
# Epoch 337/5000
#  - 0s - loss: 0.5060 - val_loss: 0.6127
# Epoch 338/5000
#  - 0s - loss: 0.5580 - val_loss: 0.6086
# Epoch 339/5000
#  - 0s - loss: 0.5212 - val_loss: 0.6298
# Epoch 340/5000
#  - 0s - loss: 0.5189 - val_loss: 0.6266
# Epoch 341/5000
#  - 0s - loss: 0.5353 - val_loss: 0.6165
# Epoch 342/5000
#  - 0s - loss: 0.5325 - val_loss: 0.6175
# Epoch 343/5000
#  - 0s - loss: 0.5184 - val_loss: 0.6210
# Epoch 344/5000
#  - 0s - loss: 0.5497 - val_loss: 0.6258
# Epoch 345/5000
#  - 0s - loss: 0.5592 - val_loss: 0.6292
# Epoch 346/5000
#  - 0s - loss: 0.5337 - val_loss: 0.6249
# Epoch 347/5000
#  - 0s - loss: 0.5388 - val_loss: 0.6116
# Epoch 348/5000
#  - 0s - loss: 0.5131 - val_loss: 0.5883
# Epoch 349/5000
#  - 0s - loss: 0.5691 - val_loss: 0.5836
# Epoch 350/5000
#  - 0s - loss: 0.5526 - val_loss: 0.6181
# Epoch 351/5000
#  - 0s - loss: 0.5289 - val_loss: 0.6107
# Epoch 352/5000
#  - 0s - loss: 0.5289 - val_loss: 0.6013
# Epoch 353/5000
#  - 0s - loss: 0.5377 - val_loss: 0.6022
# Epoch 354/5000
#  - 0s - loss: 0.5085 - val_loss: 0.5938
# Epoch 355/5000
#  - 0s - loss: 0.4969 - val_loss: 0.5904
# Epoch 356/5000
#  - 0s - loss: 0.5563 - val_loss: 0.5940
# Epoch 357/5000
#  - 0s - loss: 0.5143 - val_loss: 0.6058
# Epoch 358/5000
#  - 0s - loss: 0.5245 - val_loss: 0.6033
# Epoch 359/5000
#  - 0s - loss: 0.5618 - val_loss: 0.5971
# Epoch 360/5000
#  - 0s - loss: 0.5347 - val_loss: 0.5854
# Epoch 361/5000
#  - 0s - loss: 0.5089 - val_loss: 0.5763
# Epoch 362/5000
#  - 0s - loss: 0.5603 - val_loss: 0.5902
# Epoch 363/5000
#  - 0s - loss: 0.5298 - val_loss: 0.5895
# Epoch 364/5000
#  - 0s - loss: 0.5573 - val_loss: 0.5961
# Epoch 365/5000
#  - 0s - loss: 0.5161 - val_loss: 0.6057
# Epoch 366/5000
#  - 0s - loss: 0.5124 - val_loss: 0.6089
# Epoch 367/5000
#  - 0s - loss: 0.4993 - val_loss: 0.5960
# Epoch 368/5000
#  - 0s - loss: 0.5229 - val_loss: 0.6046
# Epoch 369/5000
#  - 0s - loss: 0.5136 - val_loss: 0.6159
# Epoch 370/5000
#  - 0s - loss: 0.5563 - val_loss: 0.5940
# Epoch 371/5000
#  - 0s - loss: 0.5255 - val_loss: 0.6079
# Epoch 372/5000
#  - 0s - loss: 0.5627 - val_loss: 0.6413
# Epoch 373/5000
#  - 0s - loss: 0.5474 - val_loss: 0.6112
# Epoch 374/5000
#  - 0s - loss: 0.5083 - val_loss: 0.6063
# Epoch 375/5000
#  - 0s - loss: 0.5493 - val_loss: 0.6024
# Epoch 376/5000
#  - 0s - loss: 0.5591 - val_loss: 0.5959
# Epoch 377/5000
#  - 0s - loss: 0.5635 - val_loss: 0.6083
# Epoch 378/5000
#  - 0s - loss: 0.5591 - val_loss: 0.6186
# Epoch 379/5000
#  - 0s - loss: 0.5385 - val_loss: 0.6100
# Epoch 380/5000
#  - 0s - loss: 0.5727 - val_loss: 0.6257
# Epoch 381/5000
#  - 0s - loss: 0.5999 - val_loss: 0.6305
# Epoch 382/5000
#  - 0s - loss: 0.5288 - val_loss: 0.6174
# Epoch 383/5000
#  - 0s - loss: 0.5332 - val_loss: 0.6092
# Epoch 384/5000
#  - 0s - loss: 0.5411 - val_loss: 0.5971
# Epoch 385/5000
#  - 0s - loss: 0.5304 - val_loss: 0.5983
# Epoch 386/5000
#  - 0s - loss: 0.4937 - val_loss: 0.5924
# Epoch 387/5000
#  - 0s - loss: 0.5128 - val_loss: 0.5985
# Epoch 388/5000
#  - 0s - loss: 0.5248 - val_loss: 0.6046
# Epoch 389/5000
#  - 0s - loss: 0.5487 - val_loss: 0.5970
# Epoch 390/5000
#  - 0s - loss: 0.5453 - val_loss: 0.5817
# Epoch 391/5000
#  - 0s - loss: 0.5325 - val_loss: 0.5934
# Epoch 392/5000
#  - 0s - loss: 0.5271 - val_loss: 0.5797
# Epoch 393/5000
#  - 0s - loss: 0.5063 - val_loss: 0.5890
# Epoch 394/5000
#  - 0s - loss: 0.5056 - val_loss: 0.6287
# Epoch 395/5000
#  - 0s - loss: 0.5091 - val_loss: 0.6033
# Epoch 396/5000
#  - 0s - loss: 0.4967 - val_loss: 0.5959
# Epoch 397/5000
#  - 0s - loss: 0.5154 - val_loss: 0.5952
# Epoch 398/5000
#  - 0s - loss: 0.5069 - val_loss: 0.6122
# Epoch 399/5000
#  - 0s - loss: 0.5211 - val_loss: 0.6324
# Epoch 400/5000
#  - 0s - loss: 0.5281 - val_loss: 0.5985
# Epoch 401/5000
#  - 0s - loss: 0.4832 - val_loss: 0.5931
# Epoch 402/5000
#  - 0s - loss: 0.5224 - val_loss: 0.6208
# Epoch 403/5000
#  - 0s - loss: 0.5079 - val_loss: 0.6152
# Epoch 404/5000
#  - 0s - loss: 0.5043 - val_loss: 0.6046
# Epoch 405/5000
#  - 0s - loss: 0.5244 - val_loss: 0.6130
# Epoch 406/5000
#  - 0s - loss: 0.5257 - val_loss: 0.6126
# Epoch 407/5000
#  - 0s - loss: 0.5464 - val_loss: 0.6110
# Epoch 408/5000
#  - 0s - loss: 0.4966 - val_loss: 0.5951
# Epoch 409/5000
#  - 0s - loss: 0.5190 - val_loss: 0.6020
# Epoch 410/5000
#  - 0s - loss: 0.5147 - val_loss: 0.6117
# Epoch 411/5000
#  - 0s - loss: 0.4658 - val_loss: 0.6354
# Epoch 412/5000
#  - 0s - loss: 0.5431 - val_loss: 0.6451
# Epoch 413/5000
#  - 0s - loss: 0.5403 - val_loss: 0.6327
# Epoch 414/5000
#  - 0s - loss: 0.4835 - val_loss: 0.6325
# Epoch 415/5000
#  - 0s - loss: 0.5307 - val_loss: 0.6374
# Epoch 416/5000
#  - 0s - loss: 0.5206 - val_loss: 0.6292
# Epoch 417/5000
#  - 0s - loss: 0.4960 - val_loss: 0.6135
# Epoch 418/5000
#  - 0s - loss: 0.5508 - val_loss: 0.5915
# Epoch 419/5000
#  - 0s - loss: 0.5434 - val_loss: 0.5832
# Epoch 420/5000
#  - 0s - loss: 0.5213 - val_loss: 0.5878
# Epoch 421/5000
#  - 0s - loss: 0.5496 - val_loss: 0.5777
# Epoch 422/5000
#  - 0s - loss: 0.5130 - val_loss: 0.5935
# Epoch 423/5000
#  - 0s - loss: 0.4987 - val_loss: 0.6040
# Epoch 424/5000
#  - 0s - loss: 0.5322 - val_loss: 0.5976
# Epoch 425/5000
#  - 0s - loss: 0.5112 - val_loss: 0.5892
# Epoch 426/5000
#  - 0s - loss: 0.5154 - val_loss: 0.5884
# Epoch 427/5000
#  - 0s - loss: 0.5056 - val_loss: 0.5948
# Epoch 428/5000
#  - 0s - loss: 0.4937 - val_loss: 0.6142
# Epoch 429/5000
#  - 0s - loss: 0.4858 - val_loss: 0.6172
# Epoch 430/5000
#  - 0s - loss: 0.5543 - val_loss: 0.6283
# Epoch 431/5000
#  - 0s - loss: 0.5036 - val_loss: 0.6142
# Epoch 432/5000
#  - 0s - loss: 0.5454 - val_loss: 0.5906
# Epoch 433/5000
#  - 0s - loss: 0.5093 - val_loss: 0.5807
# Epoch 434/5000
#  - 0s - loss: 0.4950 - val_loss: 0.5923
# Epoch 435/5000
#  - 0s - loss: 0.5360 - val_loss: 0.6069
# Epoch 436/5000
#  - 0s - loss: 0.4961 - val_loss: 0.5961
# Epoch 437/5000
#  - 0s - loss: 0.4895 - val_loss: 0.5933
# Epoch 438/5000
#  - 0s - loss: 0.4889 - val_loss: 0.6006
# Epoch 439/5000
#  - 0s - loss: 0.5089 - val_loss: 0.6087
# Epoch 440/5000
#  - 0s - loss: 0.4860 - val_loss: 0.6113
# Epoch 441/5000
#  - 0s - loss: 0.5326 - val_loss: 0.5931
# Epoch 442/5000
#  - 0s - loss: 0.5521 - val_loss: 0.5954
# Epoch 443/5000
#  - 0s - loss: 0.5163 - val_loss: 0.6093
# Epoch 444/5000
#  - 0s - loss: 0.5455 - val_loss: 0.6317
# Epoch 445/5000
#  - 0s - loss: 0.5237 - val_loss: 0.6266
# Epoch 446/5000
#  - 0s - loss: 0.5109 - val_loss: 0.6114
# Epoch 447/5000
#  - 0s - loss: 0.5106 - val_loss: 0.6107
# Epoch 448/5000
#  - 0s - loss: 0.5411 - val_loss: 0.6227
# Epoch 449/5000
#  - 0s - loss: 0.4879 - val_loss: 0.6005
# Epoch 450/5000
#  - 0s - loss: 0.4822 - val_loss: 0.5974
# Epoch 451/5000
#  - 0s - loss: 0.5234 - val_loss: 0.5881
# Epoch 452/5000
#  - 0s - loss: 0.4933 - val_loss: 0.5967
# Epoch 453/5000
#  - 0s - loss: 0.5327 - val_loss: 0.6277
# Epoch 454/5000
#  - 0s - loss: 0.5194 - val_loss: 0.6401
# Epoch 455/5000
#  - 0s - loss: 0.5230 - val_loss: 0.6195
# Epoch 456/5000
#  - 0s - loss: 0.4804 - val_loss: 0.6271
# Epoch 457/5000
#  - 0s - loss: 0.5001 - val_loss: 0.6363
# Epoch 458/5000
#  - 0s - loss: 0.5313 - val_loss: 0.6261
# Epoch 459/5000
#  - 0s - loss: 0.4965 - val_loss: 0.6092
# Epoch 460/5000
#  - 0s - loss: 0.5112 - val_loss: 0.6183
# Epoch 461/5000
#  - 0s - loss: 0.4956 - val_loss: 0.6274
# Epoch 462/5000
#  - 0s - loss: 0.5077 - val_loss: 0.6191
# Epoch 463/5000
#  - 0s - loss: 0.5235 - val_loss: 0.6094
# Epoch 464/5000
#  - 0s - loss: 0.4948 - val_loss: 0.6134
# Epoch 465/5000
#  - 0s - loss: 0.5022 - val_loss: 0.6330
# Epoch 466/5000
#  - 0s - loss: 0.4926 - val_loss: 0.6467
# Epoch 467/5000
#  - 0s - loss: 0.5491 - val_loss: 0.6302
# Epoch 468/5000
#  - 0s - loss: 0.5152 - val_loss: 0.6110
# Epoch 469/5000
#  - 0s - loss: 0.5504 - val_loss: 0.6112
# Epoch 470/5000
#  - 0s - loss: 0.5005 - val_loss: 0.6150
# Epoch 471/5000
#  - 0s - loss: 0.4975 - val_loss: 0.6027
# Epoch 472/5000
#  - 0s - loss: 0.5182 - val_loss: 0.5976
# Epoch 473/5000
#  - 0s - loss: 0.4971 - val_loss: 0.6075
# Epoch 474/5000
#  - 0s - loss: 0.5150 - val_loss: 0.6291
# Epoch 475/5000
#  - 0s - loss: 0.4814 - val_loss: 0.6337
# Epoch 476/5000
#  - 0s - loss: 0.5251 - val_loss: 0.6266
# Epoch 477/5000
#  - 0s - loss: 0.4682 - val_loss: 0.6106
# Epoch 478/5000
#  - 0s - loss: 0.4829 - val_loss: 0.5973
# Epoch 479/5000
#  - 0s - loss: 0.5037 - val_loss: 0.6165
# Epoch 480/5000
#  - 0s - loss: 0.4742 - val_loss: 0.6162
# Epoch 481/5000
#  - 0s - loss: 0.4941 - val_loss: 0.5939
# Epoch 482/5000
#  - 0s - loss: 0.5101 - val_loss: 0.6015
# Epoch 483/5000
#  - 0s - loss: 0.5381 - val_loss: 0.6225
# Epoch 484/5000
#  - 0s - loss: 0.5134 - val_loss: 0.6158
# Epoch 485/5000
#  - 0s - loss: 0.4624 - val_loss: 0.6151
# Epoch 486/5000
#  - 0s - loss: 0.4812 - val_loss: 0.6180
# Epoch 487/5000
#  - 0s - loss: 0.4904 - val_loss: 0.6376
# Epoch 488/5000
#  - 0s - loss: 0.4700 - val_loss: 0.6378
# Epoch 489/5000
#  - 0s - loss: 0.5306 - val_loss: 0.6147
# Epoch 490/5000
#  - 0s - loss: 0.5322 - val_loss: 0.6188
# Epoch 491/5000
#  - 0s - loss: 0.4854 - val_loss: 0.6243
# Epoch 492/5000
#  - 0s - loss: 0.4882 - val_loss: 0.6075
# Epoch 493/5000
#  - 0s - loss: 0.4920 - val_loss: 0.5962
# Epoch 494/5000
#  - 0s - loss: 0.5126 - val_loss: 0.6001
# Epoch 495/5000
#  - 0s - loss: 0.4958 - val_loss: 0.5981
# Epoch 496/5000
#  - 0s - loss: 0.4697 - val_loss: 0.6067
# Epoch 497/5000
#  - 0s - loss: 0.4828 - val_loss: 0.6028
# Epoch 498/5000
#  - 0s - loss: 0.4976 - val_loss: 0.6056
# Epoch 499/5000
#  - 0s - loss: 0.5267 - val_loss: 0.6074
# Epoch 500/5000
#  - 0s - loss: 0.4475 - val_loss: 0.5980
# Epoch 501/5000
#  - 0s - loss: 0.4952 - val_loss: 0.6037
# Epoch 502/5000
#  - 0s - loss: 0.4823 - val_loss: 0.6260
# Epoch 503/5000
#  - 0s - loss: 0.5235 - val_loss: 0.6409
# Epoch 504/5000
#  - 0s - loss: 0.4859 - val_loss: 0.6154
# Epoch 505/5000
#  - 0s - loss: 0.4703 - val_loss: 0.6072
# Epoch 506/5000
#  - 0s - loss: 0.4698 - val_loss: 0.5922
# Epoch 507/5000
#  - 0s - loss: 0.4860 - val_loss: 0.6041
# Epoch 508/5000
#  - 0s - loss: 0.5216 - val_loss: 0.5966
# Epoch 509/5000
#  - 0s - loss: 0.5381 - val_loss: 0.6037
# Epoch 510/5000
#  - 0s - loss: 0.5080 - val_loss: 0.6139
# Epoch 511/5000
#  - 0s - loss: 0.4956 - val_loss: 0.6229
# Epoch 512/5000
#  - 0s - loss: 0.5175 - val_loss: 0.6256
# Epoch 513/5000
#  - 0s - loss: 0.5348 - val_loss: 0.6653
# Epoch 514/5000
#  - 0s - loss: 0.5468 - val_loss: 0.6350
# Epoch 515/5000
#  - 0s - loss: 0.4778 - val_loss: 0.5985
# Epoch 516/5000
#  - 0s - loss: 0.5300 - val_loss: 0.6132
# Epoch 517/5000
#  - 0s - loss: 0.5204 - val_loss: 0.6345
# Epoch 518/5000
#  - 0s - loss: 0.5146 - val_loss: 0.5837
# Epoch 519/5000
#  - 0s - loss: 0.4933 - val_loss: 0.5836
# Epoch 520/5000
#  - 0s - loss: 0.4759 - val_loss: 0.5973
# Epoch 521/5000
#  - 0s - loss: 0.5192 - val_loss: 0.6129
# Epoch 522/5000
#  - 0s - loss: 0.4792 - val_loss: 0.6025
# Epoch 523/5000
#  - 0s - loss: 0.5158 - val_loss: 0.5948
# Epoch 524/5000
#  - 0s - loss: 0.5053 - val_loss: 0.5951
# Epoch 525/5000
#  - 0s - loss: 0.5028 - val_loss: 0.5880
# Epoch 526/5000
#  - 0s - loss: 0.5240 - val_loss: 0.6048
# Epoch 527/5000
#  - 0s - loss: 0.4930 - val_loss: 0.6078
# Epoch 528/5000
#  - 0s - loss: 0.4653 - val_loss: 0.6121
# Epoch 529/5000
#  - 0s - loss: 0.4807 - val_loss: 0.6178
# Epoch 530/5000
#  - 0s - loss: 0.5235 - val_loss: 0.6065
# Epoch 531/5000
#  - 0s - loss: 0.4723 - val_loss: 0.5909
# Epoch 532/5000
#  - 0s - loss: 0.5135 - val_loss: 0.5961
# Epoch 533/5000
#  - 0s - loss: 0.4864 - val_loss: 0.5980
# Epoch 534/5000
#  - 0s - loss: 0.4790 - val_loss: 0.6256
# Epoch 535/5000
#  - 0s - loss: 0.4565 - val_loss: 0.6045
# Epoch 536/5000
#  - 0s - loss: 0.4714 - val_loss: 0.5925
# Epoch 537/5000
#  - 0s - loss: 0.4657 - val_loss: 0.5903
# Epoch 538/5000
#  - 0s - loss: 0.5334 - val_loss: 0.5925
# Epoch 539/5000
#  - 0s - loss: 0.4901 - val_loss: 0.5913
# Epoch 540/5000
#  - 0s - loss: 0.4795 - val_loss: 0.5897
# Epoch 541/5000
#  - 0s - loss: 0.4907 - val_loss: 0.6091
# Epoch 542/5000
#  - 0s - loss: 0.4753 - val_loss: 0.6174
# Epoch 543/5000
#  - 0s - loss: 0.4881 - val_loss: 0.5950
# Epoch 544/5000
#  - 0s - loss: 0.4945 - val_loss: 0.5862
# Epoch 545/5000
#  - 0s - loss: 0.5029 - val_loss: 0.5830
# Epoch 546/5000
#  - 0s - loss: 0.4966 - val_loss: 0.5921
# Epoch 547/5000
#  - 0s - loss: 0.4757 - val_loss: 0.6048
# Epoch 548/5000
#  - 0s - loss: 0.4905 - val_loss: 0.6316
# Epoch 549/5000
#  - 0s - loss: 0.4821 - val_loss: 0.6152
# Epoch 550/5000
#  - 0s - loss: 0.4707 - val_loss: 0.6018
# Epoch 551/5000
#  - 0s - loss: 0.5045 - val_loss: 0.6441
# Epoch 552/5000
#  - 0s - loss: 0.4363 - val_loss: 0.6441
# Epoch 553/5000
#  - 0s - loss: 0.4832 - val_loss: 0.6261
# Epoch 554/5000
#  - 0s - loss: 0.5037 - val_loss: 0.6239
# Epoch 555/5000
#  - 0s - loss: 0.5275 - val_loss: 0.6114
# Epoch 556/5000
#  - 0s - loss: 0.4772 - val_loss: 0.6019
# Epoch 557/5000
#  - 0s - loss: 0.5537 - val_loss: 0.5998
# Epoch 558/5000
#  - 0s - loss: 0.5014 - val_loss: 0.6206
# Epoch 559/5000
#  - 0s - loss: 0.5101 - val_loss: 0.6285
# Epoch 560/5000
#  - 0s - loss: 0.5078 - val_loss: 0.6099
# Epoch 561/5000
#  - 0s - loss: 0.5068 - val_loss: 0.6041
# Epoch 562/5000
#  - 0s - loss: 0.4794 - val_loss: 0.6024
# Epoch 563/5000
#  - 0s - loss: 0.4572 - val_loss: 0.5951
# Epoch 564/5000
#  - 0s - loss: 0.4959 - val_loss: 0.5988
# Epoch 565/5000
#  - 0s - loss: 0.4537 - val_loss: 0.5964
# Epoch 566/5000
#  - 0s - loss: 0.5213 - val_loss: 0.6071
# Epoch 567/5000
#  - 0s - loss: 0.4632 - val_loss: 0.6034
# Epoch 568/5000
#  - 0s - loss: 0.5204 - val_loss: 0.5889
# Epoch 569/5000
#  - 0s - loss: 0.5130 - val_loss: 0.5929
# Epoch 570/5000
#  - 0s - loss: 0.4797 - val_loss: 0.6093
# Epoch 571/5000
#  - 0s - loss: 0.5708 - val_loss: 0.5868
# Epoch 572/5000
#  - 0s - loss: 0.4946 - val_loss: 0.5910
# Epoch 573/5000
#  - 0s - loss: 0.5144 - val_loss: 0.6106
# Epoch 574/5000
#  - 0s - loss: 0.4728 - val_loss: 0.6123
# Epoch 575/5000
#  - 0s - loss: 0.4725 - val_loss: 0.5974
# Epoch 576/5000
#  - 0s - loss: 0.4858 - val_loss: 0.6015
# Epoch 577/5000
#  - 0s - loss: 0.4965 - val_loss: 0.6112
# Epoch 578/5000
#  - 0s - loss: 0.4824 - val_loss: 0.6203
# Epoch 579/5000
#  - 0s - loss: 0.4874 - val_loss: 0.6349
# Epoch 580/5000
#  - 0s - loss: 0.4758 - val_loss: 0.6451
# Epoch 581/5000
#  - 0s - loss: 0.5047 - val_loss: 0.6331
# Epoch 582/5000
#  - 0s - loss: 0.4463 - val_loss: 0.6217
# Epoch 583/5000
#  - 0s - loss: 0.4823 - val_loss: 0.6203
# Epoch 584/5000
#  - 0s - loss: 0.4311 - val_loss: 0.6375
# Epoch 585/5000
#  - 0s - loss: 0.5506 - val_loss: 0.6287
# Epoch 586/5000
#  - 0s - loss: 0.4800 - val_loss: 0.6177
# Epoch 587/5000
#  - 0s - loss: 0.4679 - val_loss: 0.6128
# Epoch 588/5000
#  - 0s - loss: 0.4973 - val_loss: 0.6189
# Epoch 589/5000
#  - 0s - loss: 0.4629 - val_loss: 0.6177
# Epoch 590/5000
#  - 0s - loss: 0.4830 - val_loss: 0.6095
# Epoch 591/5000
#  - 0s - loss: 0.5117 - val_loss: 0.5955
# Epoch 592/5000
#  - 0s - loss: 0.4658 - val_loss: 0.6052
# Epoch 593/5000
#  - 0s - loss: 0.4671 - val_loss: 0.6228
# Epoch 594/5000
#  - 0s - loss: 0.4982 - val_loss: 0.6271
# Epoch 595/5000
#  - 0s - loss: 0.5193 - val_loss: 0.6276
# Epoch 596/5000
#  - 0s - loss: 0.4406 - val_loss: 0.6331
# Epoch 597/5000
#  - 0s - loss: 0.4867 - val_loss: 0.6335
# Epoch 598/5000
#  - 0s - loss: 0.4740 - val_loss: 0.6230
# Epoch 599/5000
#  - 0s - loss: 0.4344 - val_loss: 0.6154
# Epoch 600/5000
#  - 0s - loss: 0.4646 - val_loss: 0.6133
# Epoch 601/5000
#  - 0s - loss: 0.4617 - val_loss: 0.6150
# Epoch 602/5000
#  - 0s - loss: 0.4865 - val_loss: 0.6291
# Epoch 603/5000
#  - 0s - loss: 0.4784 - val_loss: 0.6189
# Epoch 604/5000
#  - 0s - loss: 0.4651 - val_loss: 0.6028
# Epoch 605/5000
#  - 0s - loss: 0.5000 - val_loss: 0.5961
# Epoch 606/5000
#  - 0s - loss: 0.4408 - val_loss: 0.6073
# Epoch 607/5000
#  - 0s - loss: 0.4594 - val_loss: 0.6144
# Epoch 608/5000
#  - 0s - loss: 0.4818 - val_loss: 0.6194
# Epoch 609/5000
#  - 0s - loss: 0.4559 - val_loss: 0.6122
# Epoch 610/5000
#  - 0s - loss: 0.4759 - val_loss: 0.6024
# Epoch 611/5000
#  - 0s - loss: 0.4604 - val_loss: 0.6075
# Epoch 612/5000
#  - 0s - loss: 0.4443 - val_loss: 0.6431
# Epoch 613/5000
#  - 0s - loss: 0.4893 - val_loss: 0.6157
# Epoch 614/5000
#  - 0s - loss: 0.4728 - val_loss: 0.6053
# Epoch 615/5000
#  - 0s - loss: 0.4896 - val_loss: 0.6373
# Epoch 616/5000
#  - 0s - loss: 0.4612 - val_loss: 0.6496
# Epoch 617/5000
#  - 0s - loss: 0.4530 - val_loss: 0.6433
# Epoch 618/5000
#  - 0s - loss: 0.4894 - val_loss: 0.6406
# Epoch 619/5000
#  - 0s - loss: 0.4876 - val_loss: 0.6470
# Epoch 620/5000
#  - 0s - loss: 0.5165 - val_loss: 0.6406
# Epoch 621/5000
#  - 0s - loss: 0.4838 - val_loss: 0.6470
# Epoch 622/5000
#  - 0s - loss: 0.4594 - val_loss: 0.6555
# Epoch 623/5000
#  - 0s - loss: 0.4357 - val_loss: 0.6215
# Epoch 624/5000
#  - 0s - loss: 0.4780 - val_loss: 0.6309
# Epoch 625/5000
#  - 0s - loss: 0.4957 - val_loss: 0.6429
# Epoch 626/5000
#  - 0s - loss: 0.4812 - val_loss: 0.6409
# Epoch 627/5000
#  - 0s - loss: 0.4603 - val_loss: 0.6203
# Epoch 628/5000
#  - 0s - loss: 0.4250 - val_loss: 0.6319
# Epoch 629/5000
#  - 0s - loss: 0.4823 - val_loss: 0.6281
# Epoch 630/5000
#  - 0s - loss: 0.4523 - val_loss: 0.6217
# Epoch 631/5000
#  - 0s - loss: 0.4645 - val_loss: 0.6180
# Epoch 632/5000
#  - 0s - loss: 0.4541 - val_loss: 0.5999
# Epoch 633/5000
#  - 0s - loss: 0.4653 - val_loss: 0.5915
# Epoch 634/5000
#  - 0s - loss: 0.5199 - val_loss: 0.5902
# Epoch 635/5000
#  - 0s - loss: 0.4415 - val_loss: 0.6056
# Epoch 636/5000
#  - 0s - loss: 0.4756 - val_loss: 0.5956
# Epoch 637/5000
#  - 0s - loss: 0.5192 - val_loss: 0.6111
# Epoch 638/5000
#  - 0s - loss: 0.4988 - val_loss: 0.6176
# Epoch 639/5000
#  - 0s - loss: 0.5054 - val_loss: 0.6156
# Epoch 640/5000
#  - 0s - loss: 0.4396 - val_loss: 0.6131
# Epoch 641/5000
#  - 0s - loss: 0.4755 - val_loss: 0.6311
# Epoch 642/5000
#  - 0s - loss: 0.4757 - val_loss: 0.6127
# Epoch 643/5000
#  - 0s - loss: 0.4436 - val_loss: 0.6044
# Epoch 644/5000
#  - 0s - loss: 0.4389 - val_loss: 0.6055
# Epoch 645/5000
#  - 0s - loss: 0.4794 - val_loss: 0.6651
# Epoch 646/5000
#  - 0s - loss: 0.4853 - val_loss: 0.6475
# Epoch 647/5000
#  - 0s - loss: 0.4669 - val_loss: 0.6253
# Epoch 648/5000
#  - 0s - loss: 0.5006 - val_loss: 0.6115
# Epoch 649/5000
#  - 0s - loss: 0.4822 - val_loss: 0.6037
# Epoch 650/5000
#  - 0s - loss: 0.4912 - val_loss: 0.6279
# Epoch 651/5000
#  - 0s - loss: 0.5112 - val_loss: 0.5892
# Epoch 652/5000
#  - 0s - loss: 0.5158 - val_loss: 0.6081
# Epoch 653/5000
#  - 0s - loss: 0.4860 - val_loss: 0.6350
# Epoch 654/5000
#  - 0s - loss: 0.4684 - val_loss: 0.6543
# Epoch 655/5000
#  - 0s - loss: 0.4980 - val_loss: 0.6299
# Epoch 656/5000
#  - 0s - loss: 0.4878 - val_loss: 0.6209
# Epoch 657/5000
#  - 0s - loss: 0.4926 - val_loss: 0.6331
# Epoch 658/5000
#  - 0s - loss: 0.4946 - val_loss: 0.6460
# Epoch 659/5000
#  - 0s - loss: 0.4668 - val_loss: 0.6411
# Epoch 660/5000
#  - 0s - loss: 0.4658 - val_loss: 0.6342
# Epoch 661/5000
#  - 0s - loss: 0.5041 - val_loss: 0.6399
# Epoch 662/5000
#  - 0s - loss: 0.4706 - val_loss: 0.6333
# Epoch 663/5000
#  - 0s - loss: 0.4753 - val_loss: 0.6179
# Epoch 664/5000
#  - 0s - loss: 0.4756 - val_loss: 0.6065
# Epoch 665/5000
#  - 0s - loss: 0.4859 - val_loss: 0.6039
# Epoch 666/5000
#  - 0s - loss: 0.4926 - val_loss: 0.5954
# Epoch 667/5000
#  - 0s - loss: 0.4914 - val_loss: 0.6075
# Epoch 668/5000
#  - 0s - loss: 0.4747 - val_loss: 0.6292
# Epoch 669/5000
#  - 0s - loss: 0.4434 - val_loss: 0.6198
# Epoch 670/5000
#  - 0s - loss: 0.4713 - val_loss: 0.6291
# Epoch 671/5000
#  - 0s - loss: 0.4866 - val_loss: 0.6195
# Epoch 672/5000
#  - 0s - loss: 0.4539 - val_loss: 0.6360
# Epoch 673/5000
#  - 0s - loss: 0.4436 - val_loss: 0.6271
# Epoch 674/5000
#  - 0s - loss: 0.4503 - val_loss: 0.6378
# Epoch 675/5000
#  - 0s - loss: 0.4876 - val_loss: 0.6347
# Epoch 676/5000
#  - 0s - loss: 0.4558 - val_loss: 0.6249
# Epoch 677/5000
#  - 0s - loss: 0.4730 - val_loss: 0.6094
# Epoch 678/5000
#  - 0s - loss: 0.4535 - val_loss: 0.6133
# Epoch 679/5000
#  - 0s - loss: 0.4954 - val_loss: 0.6082
# Epoch 680/5000
#  - 0s - loss: 0.4485 - val_loss: 0.6073
# Epoch 681/5000
#  - 0s - loss: 0.4370 - val_loss: 0.6064
# Epoch 682/5000
#  - 0s - loss: 0.4749 - val_loss: 0.6135
# Epoch 683/5000
#  - 0s - loss: 0.4442 - val_loss: 0.6267
# Epoch 684/5000
#  - 0s - loss: 0.4793 - val_loss: 0.6143
# Epoch 685/5000
#  - 0s - loss: 0.4433 - val_loss: 0.6106
# Epoch 686/5000
#  - 0s - loss: 0.4483 - val_loss: 0.6236
# Epoch 687/5000
#  - 0s - loss: 0.4880 - val_loss: 0.6299
# Epoch 688/5000
#  - 0s - loss: 0.4268 - val_loss: 0.6312
# Epoch 689/5000
#  - 0s - loss: 0.4941 - val_loss: 0.6297
# Epoch 690/5000
#  - 0s - loss: 0.4616 - val_loss: 0.6590
# Epoch 691/5000
#  - 0s - loss: 0.4664 - val_loss: 0.6471
# Epoch 692/5000
#  - 0s - loss: 0.5174 - val_loss: 0.6226
# Epoch 693/5000
#  - 0s - loss: 0.4852 - val_loss: 0.6207
# Epoch 694/5000
#  - 0s - loss: 0.4609 - val_loss: 0.6335
# Epoch 695/5000
#  - 0s - loss: 0.4519 - val_loss: 0.6486
# Epoch 696/5000
#  - 0s - loss: 0.5080 - val_loss: 0.6533
# Epoch 697/5000
#  - 0s - loss: 0.4660 - val_loss: 0.6568
# Epoch 698/5000
#  - 0s - loss: 0.4931 - val_loss: 0.6817
# Epoch 699/5000
#  - 0s - loss: 0.4647 - val_loss: 0.6418
# Epoch 700/5000
#  - 0s - loss: 0.5052 - val_loss: 0.6407
# Epoch 701/5000
#  - 0s - loss: 0.4920 - val_loss: 0.6363
# Epoch 702/5000
#  - 0s - loss: 0.4810 - val_loss: 0.6517
# Epoch 703/5000
#  - 0s - loss: 0.4834 - val_loss: 0.6546
# Epoch 704/5000
#  - 0s - loss: 0.4354 - val_loss: 0.6487
# Epoch 705/5000
#  - 0s - loss: 0.4790 - val_loss: 0.6317
# Epoch 706/5000
#  - 0s - loss: 0.4651 - val_loss: 0.6429
# Epoch 707/5000
#  - 0s - loss: 0.4728 - val_loss: 0.6344
# Epoch 708/5000
#  - 0s - loss: 0.4445 - val_loss: 0.6270
# Epoch 709/5000
#  - 0s - loss: 0.4720 - val_loss: 0.6171
# Epoch 710/5000
#  - 0s - loss: 0.4950 - val_loss: 0.6593
# Epoch 711/5000
#  - 0s - loss: 0.4547 - val_loss: 0.6298
# Epoch 712/5000
#  - 0s - loss: 0.4636 - val_loss: 0.5929
# Epoch 713/5000
#  - 0s - loss: 0.4704 - val_loss: 0.5997
# Epoch 714/5000
#  - 0s - loss: 0.4886 - val_loss: 0.6207
# Epoch 715/5000
#  - 0s - loss: 0.4802 - val_loss: 0.6046
# Epoch 716/5000
#  - 0s - loss: 0.4670 - val_loss: 0.5983
# Epoch 717/5000
#  - 0s - loss: 0.4852 - val_loss: 0.6025
# Epoch 718/5000
#  - 0s - loss: 0.4525 - val_loss: 0.6061
# Epoch 719/5000
#  - 0s - loss: 0.5063 - val_loss: 0.6086
# Epoch 720/5000
#  - 0s - loss: 0.4941 - val_loss: 0.6261
# Epoch 721/5000
#  - 0s - loss: 0.5189 - val_loss: 0.6251
# Epoch 722/5000
#  - 0s - loss: 0.4995 - val_loss: 0.6062
# Epoch 723/5000
#  - 0s - loss: 0.4933 - val_loss: 0.6143
# Epoch 724/5000
#  - 0s - loss: 0.4968 - val_loss: 0.6215
# Epoch 725/5000
#  - 0s - loss: 0.4752 - val_loss: 0.6213
# Epoch 726/5000
#  - 0s - loss: 0.4459 - val_loss: 0.6212
# Epoch 727/5000
#  - 0s - loss: 0.4310 - val_loss: 0.6109
# Epoch 728/5000
#  - 0s - loss: 0.4718 - val_loss: 0.6274
# Epoch 729/5000
#  - 0s - loss: 0.4898 - val_loss: 0.6359
# Epoch 730/5000
#  - 0s - loss: 0.4949 - val_loss: 0.6008
# Epoch 731/5000
#  - 0s - loss: 0.4860 - val_loss: 0.6040
# Epoch 732/5000
#  - 0s - loss: 0.4602 - val_loss: 0.5986
# Epoch 733/5000
#  - 0s - loss: 0.4589 - val_loss: 0.6023
# Epoch 734/5000
#  - 0s - loss: 0.4776 - val_loss: 0.5969
# Epoch 735/5000
#  - 0s - loss: 0.5034 - val_loss: 0.6070
# Epoch 736/5000
#  - 0s - loss: 0.4798 - val_loss: 0.6322
# Epoch 737/5000
#  - 0s - loss: 0.4589 - val_loss: 0.6297
# Epoch 738/5000
#  - 0s - loss: 0.4658 - val_loss: 0.6106
# Epoch 739/5000
#  - 0s - loss: 0.4824 - val_loss: 0.6104
# Epoch 740/5000
#  - 0s - loss: 0.4536 - val_loss: 0.6181
# Epoch 741/5000
#  - 0s - loss: 0.4378 - val_loss: 0.6235
# Epoch 742/5000
#  - 0s - loss: 0.5148 - val_loss: 0.6530
# Epoch 743/5000
#  - 0s - loss: 0.4646 - val_loss: 0.6321
# Epoch 744/5000
#  - 0s - loss: 0.4626 - val_loss: 0.6235
# Epoch 745/5000
#  - 0s - loss: 0.4735 - val_loss: 0.6568
# Epoch 746/5000
#  - 0s - loss: 0.5211 - val_loss: 0.6746
# Epoch 747/5000
#  - 0s - loss: 0.4275 - val_loss: 0.6136
# Epoch 748/5000
#  - 0s - loss: 0.4545 - val_loss: 0.6134
# Epoch 749/5000
#  - 0s - loss: 0.4346 - val_loss: 0.6124
# Epoch 750/5000
#  - 0s - loss: 0.4786 - val_loss: 0.6213
# Epoch 751/5000
#  - 0s - loss: 0.4804 - val_loss: 0.6097
# Epoch 752/5000
#  - 0s - loss: 0.4687 - val_loss: 0.6135
# Epoch 753/5000
#  - 0s - loss: 0.4740 - val_loss: 0.6177
# Epoch 754/5000
#  - 0s - loss: 0.4383 - val_loss: 0.6327
# Epoch 755/5000
#  - 0s - loss: 0.4635 - val_loss: 0.6296
# Epoch 756/5000
#  - 0s - loss: 0.4647 - val_loss: 0.6387
# Epoch 757/5000
#  - 0s - loss: 0.4641 - val_loss: 0.6291
# Epoch 758/5000
#  - 0s - loss: 0.4950 - val_loss: 0.6242
# Epoch 759/5000
#  - 0s - loss: 0.4128 - val_loss: 0.6088
# Epoch 760/5000
#  - 0s - loss: 0.4620 - val_loss: 0.5976
# Epoch 761/5000
#  - 0s - loss: 0.4728 - val_loss: 0.6069
# Epoch 762/5000
#  - 0s - loss: 0.4598 - val_loss: 0.6128
# Epoch 763/5000
#  - 0s - loss: 0.4272 - val_loss: 0.6116
# Epoch 764/5000
#  - 0s - loss: 0.4690 - val_loss: 0.6199
# Epoch 765/5000
#  - 0s - loss: 0.4856 - val_loss: 0.6292
# Epoch 766/5000
#  - 0s - loss: 0.4371 - val_loss: 0.6009
# Epoch 767/5000
#  - 0s - loss: 0.4298 - val_loss: 0.5985
# Epoch 768/5000
#  - 0s - loss: 0.4824 - val_loss: 0.6155
# Epoch 769/5000
#  - 0s - loss: 0.4443 - val_loss: 0.6260
# Epoch 770/5000
#  - 0s - loss: 0.4233 - val_loss: 0.6409
# Epoch 771/5000
#  - 0s - loss: 0.4604 - val_loss: 0.6381
# Epoch 772/5000
#  - 0s - loss: 0.4347 - val_loss: 0.6262
# Epoch 773/5000
#  - 0s - loss: 0.4380 - val_loss: 0.6215
# Epoch 774/5000
#  - 0s - loss: 0.4725 - val_loss: 0.6023
# Epoch 775/5000
#  - 0s - loss: 0.4324 - val_loss: 0.6013
# Epoch 776/5000
#  - 0s - loss: 0.4610 - val_loss: 0.6125
# Epoch 777/5000
#  - 0s - loss: 0.4212 - val_loss: 0.6164
# Epoch 778/5000
#  - 0s - loss: 0.4463 - val_loss: 0.6175
# Epoch 779/5000
#  - 0s - loss: 0.4554 - val_loss: 0.6425
# Epoch 780/5000
#  - 0s - loss: 0.4451 - val_loss: 0.6310
# Epoch 781/5000
#  - 0s - loss: 0.4782 - val_loss: 0.6405
# Epoch 782/5000
#  - 0s - loss: 0.4793 - val_loss: 0.6345
# Epoch 783/5000
#  - 0s - loss: 0.4838 - val_loss: 0.6120
# Epoch 784/5000
#  - 0s - loss: 0.4743 - val_loss: 0.6048
# Epoch 785/5000
#  - 0s - loss: 0.4193 - val_loss: 0.6055
# Epoch 786/5000
#  - 0s - loss: 0.4530 - val_loss: 0.6201
# Epoch 787/5000
#  - 0s - loss: 0.4762 - val_loss: 0.6323
# Epoch 788/5000
#  - 0s - loss: 0.4845 - val_loss: 0.6277
# Epoch 789/5000
#  - 0s - loss: 0.4273 - val_loss: 0.6367
# Epoch 790/5000
#  - 0s - loss: 0.4688 - val_loss: 0.6317
# Epoch 791/5000
#  - 0s - loss: 0.4317 - val_loss: 0.6311
# Epoch 792/5000
#  - 0s - loss: 0.4529 - val_loss: 0.6208
# Epoch 793/5000
#  - 0s - loss: 0.4634 - val_loss: 0.6338
# Epoch 794/5000
#  - 0s - loss: 0.4527 - val_loss: 0.6467
# Epoch 795/5000
#  - 0s - loss: 0.5001 - val_loss: 0.6504
# Epoch 796/5000
#  - 0s - loss: 0.4538 - val_loss: 0.6456
# Epoch 797/5000
#  - 0s - loss: 0.4708 - val_loss: 0.6344
# Epoch 798/5000
#  - 0s - loss: 0.4502 - val_loss: 0.6345
# Epoch 799/5000
#  - 0s - loss: 0.4656 - val_loss: 0.6390
# Epoch 800/5000
#  - 0s - loss: 0.4284 - val_loss: 0.6464
# Epoch 801/5000
#  - 0s - loss: 0.4619 - val_loss: 0.6172
# Epoch 802/5000
#  - 0s - loss: 0.4618 - val_loss: 0.6148
# Epoch 803/5000
#  - 0s - loss: 0.4525 - val_loss: 0.6279
# Epoch 804/5000
#  - 0s - loss: 0.4472 - val_loss: 0.6244
# Epoch 805/5000
#  - 0s - loss: 0.4904 - val_loss: 0.6138
# Epoch 806/5000
#  - 0s - loss: 0.4469 - val_loss: 0.6203
# Epoch 807/5000
#  - 0s - loss: 0.4534 - val_loss: 0.6147
# Epoch 808/5000
#  - 0s - loss: 0.4335 - val_loss: 0.6054
# Epoch 809/5000
#  - 0s - loss: 0.4480 - val_loss: 0.6280
# Epoch 810/5000
#  - 0s - loss: 0.4814 - val_loss: 0.6515
# Epoch 811/5000
#  - 0s - loss: 0.4579 - val_loss: 0.6385
# Epoch 812/5000
#  - 0s - loss: 0.4632 - val_loss: 0.6305
# Epoch 813/5000
#  - 0s - loss: 0.4643 - val_loss: 0.6226
# Epoch 814/5000
#  - 0s - loss: 0.4865 - val_loss: 0.6098
# Epoch 815/5000
#  - 0s - loss: 0.4526 - val_loss: 0.6121
# Epoch 816/5000
#  - 0s - loss: 0.4371 - val_loss: 0.6176
# Epoch 817/5000
#  - 0s - loss: 0.4592 - val_loss: 0.6459
# Epoch 818/5000
#  - 0s - loss: 0.4818 - val_loss: 0.6445
# Epoch 819/5000
#  - 0s - loss: 0.4775 - val_loss: 0.6577
# Epoch 820/5000
#  - 0s - loss: 0.4731 - val_loss: 0.6269
# Epoch 821/5000
#  - 0s - loss: 0.4501 - val_loss: 0.6133
# Epoch 822/5000
#  - 0s - loss: 0.4914 - val_loss: 0.6004
# Epoch 823/5000
#  - 0s - loss: 0.4654 - val_loss: 0.6128
# Epoch 824/5000
#  - 0s - loss: 0.4960 - val_loss: 0.6370
# Epoch 825/5000
#  - 0s - loss: 0.4653 - val_loss: 0.6204
# Epoch 826/5000
#  - 0s - loss: 0.4330 - val_loss: 0.6213
# Epoch 827/5000
#  - 0s - loss: 0.4363 - val_loss: 0.6351
# Epoch 828/5000
#  - 0s - loss: 0.4614 - val_loss: 0.6424
# Epoch 829/5000
#  - 0s - loss: 0.4926 - val_loss: 0.6226
# Epoch 830/5000
#  - 0s - loss: 0.4783 - val_loss: 0.6199
# Epoch 831/5000
#  - 0s - loss: 0.4347 - val_loss: 0.6347
# Epoch 832/5000
#  - 0s - loss: 0.4430 - val_loss: 0.6162
# Epoch 833/5000
#  - 0s - loss: 0.4427 - val_loss: 0.6155
# Epoch 834/5000
#  - 0s - loss: 0.4987 - val_loss: 0.6148
# Epoch 835/5000
#  - 0s - loss: 0.4123 - val_loss: 0.6359
# Epoch 836/5000
#  - 0s - loss: 0.4665 - val_loss: 0.6438
# Epoch 837/5000
#  - 0s - loss: 0.4784 - val_loss: 0.6486
# Epoch 838/5000
#  - 0s - loss: 0.4200 - val_loss: 0.6540
# Epoch 839/5000
#  - 0s - loss: 0.4031 - val_loss: 0.6386
# Epoch 840/5000
#  - 0s - loss: 0.4045 - val_loss: 0.6159
# Epoch 841/5000
#  - 0s - loss: 0.4691 - val_loss: 0.6185
# Epoch 842/5000
#  - 0s - loss: 0.4378 - val_loss: 0.6477
# Epoch 843/5000
#  - 0s - loss: 0.4668 - val_loss: 0.6294
# Epoch 844/5000
#  - 0s - loss: 0.4480 - val_loss: 0.6392
# Epoch 845/5000
# ...
#  - 0s - loss: 0.3140 - val_loss: 0.6076
# Epoch 4716/5000
#  - 0s - loss: 0.3439 - val_loss: 0.6038
# Epoch 4717/5000
#  - 0s - loss: 0.3138 - val_loss: 0.5960
# Epoch 4718/5000
#  - 0s - loss: 0.3413 - val_loss: 0.5872
# Epoch 4719/5000
#  - 0s - loss: 0.3704 - val_loss: 0.5840
# Epoch 4720/5000
#  - 0s - loss: 0.3740 - val_loss: 0.5857
# Epoch 4721/5000
#  - 0s - loss: 0.3784 - val_loss: 0.5976
# Epoch 4722/5000
#  - 0s - loss: 0.3296 - val_loss: 0.6132
# Epoch 4723/5000
#  - 0s - loss: 0.3379 - val_loss: 0.5892
# Epoch 4724/5000
#  - 0s - loss: 0.3586 - val_loss: 0.5747
# Epoch 4725/5000
#  - 0s - loss: 0.3447 - val_loss: 0.5749
# Epoch 4726/5000
#  - 0s - loss: 0.3652 - val_loss: 0.5746
# Epoch 4727/5000
#  - 0s - loss: 0.3435 - val_loss: 0.5791
# Epoch 4728/5000
#  - 0s - loss: 0.3517 - val_loss: 0.5758
# Epoch 4729/5000
#  - 0s - loss: 0.3648 - val_loss: 0.5680
# Epoch 4730/5000
#  - 0s - loss: 0.3414 - val_loss: 0.5678
# Epoch 4731/5000
#  - 0s - loss: 0.3517 - val_loss: 0.5727
# Epoch 4732/5000
#  - 0s - loss: 0.3464 - val_loss: 0.5806
# Epoch 4733/5000
#  - 0s - loss: 0.3224 - val_loss: 0.5850
# Epoch 4734/5000
#  - 0s - loss: 0.3325 - val_loss: 0.6099
# Epoch 4735/5000
#  - 0s - loss: 0.3246 - val_loss: 0.6229
# Epoch 4736/5000
#  - 0s - loss: 0.3979 - val_loss: 0.6271
# Epoch 4737/5000
#  - 0s - loss: 0.3572 - val_loss: 0.6423
# Epoch 4738/5000
#  - 0s - loss: 0.3233 - val_loss: 0.6509
# Epoch 4739/5000
#  - 0s - loss: 0.3441 - val_loss: 0.6427
# Epoch 4740/5000
#  - 0s - loss: 0.3441 - val_loss: 0.6189
# Epoch 4741/5000
#  - 0s - loss: 0.3422 - val_loss: 0.5996
# Epoch 4742/5000
#  - 0s - loss: 0.3571 - val_loss: 0.5885
# Epoch 4743/5000
#  - 0s - loss: 0.3484 - val_loss: 0.5887
# Epoch 4744/5000
#  - 0s - loss: 0.3970 - val_loss: 0.5922
# Epoch 4745/5000
#  - 0s - loss: 0.3232 - val_loss: 0.5814
# Epoch 4746/5000
#  - 0s - loss: 0.3339 - val_loss: 0.5810
# Epoch 4747/5000
#  - 0s - loss: 0.3340 - val_loss: 0.5790
# Epoch 4748/5000
#  - 0s - loss: 0.3719 - val_loss: 0.6003
# Epoch 4749/5000
#  - 0s - loss: 0.3364 - val_loss: 0.6288
# Epoch 4750/5000
#  - 0s - loss: 0.3612 - val_loss: 0.6252
# Epoch 4751/5000
#  - 0s - loss: 0.3259 - val_loss: 0.6184
# Epoch 4752/5000
#  - 0s - loss: 0.3180 - val_loss: 0.6271
# Epoch 4753/5000
#  - 0s - loss: 0.3712 - val_loss: 0.6374
# Epoch 4754/5000
#  - 0s - loss: 0.3517 - val_loss: 0.6489
# Epoch 4755/5000
#  - 0s - loss: 0.3552 - val_loss: 0.6592
# Epoch 4756/5000
#  - 0s - loss: 0.3936 - val_loss: 0.6648
# Epoch 4757/5000
#  - 0s - loss: 0.4266 - val_loss: 0.6574
# Epoch 4758/5000
#  - 0s - loss: 0.3669 - val_loss: 0.6232
# Epoch 4759/5000
#  - 0s - loss: 0.3436 - val_loss: 0.6073
# Epoch 4760/5000
#  - 0s - loss: 0.3521 - val_loss: 0.6033
# Epoch 4761/5000
#  - 0s - loss: 0.3497 - val_loss: 0.6043
# Epoch 4762/5000
#  - 0s - loss: 0.3020 - val_loss: 0.6147
# Epoch 4763/5000
#  - 0s - loss: 0.3400 - val_loss: 0.6274
# Epoch 4764/5000
#  - 0s - loss: 0.3676 - val_loss: 0.6197
# Epoch 4765/5000
#  - 0s - loss: 0.3500 - val_loss: 0.6038
# Epoch 4766/5000
#  - 0s - loss: 0.3520 - val_loss: 0.6160
# Epoch 4767/5000
#  - 0s - loss: 0.3778 - val_loss: 0.6231
# Epoch 4768/5000
#  - 0s - loss: 0.3405 - val_loss: 0.6138
# Epoch 4769/5000
#  - 0s - loss: 0.3751 - val_loss: 0.6105
# Epoch 4770/5000
#  - 0s - loss: 0.3208 - val_loss: 0.6090
# Epoch 4771/5000
#  - 0s - loss: 0.3490 - val_loss: 0.5989
# Epoch 4772/5000
#  - 0s - loss: 0.3335 - val_loss: 0.6060
# Epoch 4773/5000
#  - 0s - loss: 0.3495 - val_loss: 0.6024
# Epoch 4774/5000
#  - 0s - loss: 0.3244 - val_loss: 0.6074
# Epoch 4775/5000
#  - 0s - loss: 0.3346 - val_loss: 0.6096
# Epoch 4776/5000
#  - 0s - loss: 0.3714 - val_loss: 0.6170
# Epoch 4777/5000
#  - 0s - loss: 0.3747 - val_loss: 0.6181
# Epoch 4778/5000
#  - 0s - loss: 0.3305 - val_loss: 0.6128
# Epoch 4779/5000
#  - 0s - loss: 0.3916 - val_loss: 0.6084
# Epoch 4780/5000
#  - 0s - loss: 0.3304 - val_loss: 0.6112
# Epoch 4781/5000
#  - 0s - loss: 0.3157 - val_loss: 0.6367
# Epoch 4782/5000
#  - 0s - loss: 0.3694 - val_loss: 0.6045
# Epoch 4783/5000
#  - 0s - loss: 0.3405 - val_loss: 0.6144
# Epoch 4784/5000
#  - 0s - loss: 0.3856 - val_loss: 0.6183
# Epoch 4785/5000
#  - 0s - loss: 0.3440 - val_loss: 0.6156
# Epoch 4786/5000
#  - 0s - loss: 0.3440 - val_loss: 0.6261
# Epoch 4787/5000
#  - 0s - loss: 0.3794 - val_loss: 0.6176
# Epoch 4788/5000
#  - 0s - loss: 0.3523 - val_loss: 0.6156
# Epoch 4789/5000
#  - 0s - loss: 0.3567 - val_loss: 0.6150
# Epoch 4790/5000
#  - 0s - loss: 0.3613 - val_loss: 0.6109
# Epoch 4791/5000
#  - 0s - loss: 0.3323 - val_loss: 0.6207
# Epoch 4792/5000
#  - 0s - loss: 0.3258 - val_loss: 0.6249
# Epoch 4793/5000
#  - 0s - loss: 0.3621 - val_loss: 0.6430
# Epoch 4794/5000
#  - 0s - loss: 0.3669 - val_loss: 0.6187
# Epoch 4795/5000
#  - 0s - loss: 0.3586 - val_loss: 0.6017
# Epoch 4796/5000
#  - 0s - loss: 0.3352 - val_loss: 0.5923
# Epoch 4797/5000
#  - 0s - loss: 0.3719 - val_loss: 0.5856
# Epoch 4798/5000
#  - 0s - loss: 0.3841 - val_loss: 0.5899
# Epoch 4799/5000
#  - 0s - loss: 0.3238 - val_loss: 0.5930
# Epoch 4800/5000
#  - 0s - loss: 0.3705 - val_loss: 0.5914
# Epoch 4801/5000
#  - 0s - loss: 0.3256 - val_loss: 0.5940
# Epoch 4802/5000
#  - 0s - loss: 0.3243 - val_loss: 0.6122
# Epoch 4803/5000
#  - 0s - loss: 0.3380 - val_loss: 0.6230
# Epoch 4804/5000
#  - 0s - loss: 0.3176 - val_loss: 0.6289
# Epoch 4805/5000
#  - 0s - loss: 0.3509 - val_loss: 0.6299
# Epoch 4806/5000
#  - 0s - loss: 0.3355 - val_loss: 0.6238
# Epoch 4807/5000
#  - 0s - loss: 0.3790 - val_loss: 0.6239
# Epoch 4808/5000
#  - 0s - loss: 0.2995 - val_loss: 0.6335
# Epoch 4809/5000
#  - 0s - loss: 0.3518 - val_loss: 0.6464
# Epoch 4810/5000
#  - 0s - loss: 0.4108 - val_loss: 0.6411
# Epoch 4811/5000
#  - 0s - loss: 0.3130 - val_loss: 0.6319
# Epoch 4812/5000
#  - 0s - loss: 0.3555 - val_loss: 0.6258
# Epoch 4813/5000
#  - 0s - loss: 0.3667 - val_loss: 0.6386
# Epoch 4814/5000
#  - 0s - loss: 0.3487 - val_loss: 0.6427
# Epoch 4815/5000
#  - 0s - loss: 0.3456 - val_loss: 0.6286
# Epoch 4816/5000
#  - 0s - loss: 0.4072 - val_loss: 0.6294
# Epoch 4817/5000
#  - 0s - loss: 0.3355 - val_loss: 0.6308
# Epoch 4818/5000
#  - 0s - loss: 0.3499 - val_loss: 0.6292
# Epoch 4819/5000
#  - 0s - loss: 0.3022 - val_loss: 0.6360
# Epoch 4820/5000
#  - 0s - loss: 0.3518 - val_loss: 0.6373
# Epoch 4821/5000
#  - 0s - loss: 0.3456 - val_loss: 0.6289
# Epoch 4822/5000
#  - 0s - loss: 0.3678 - val_loss: 0.6194
# Epoch 4823/5000
#  - 0s - loss: 0.3348 - val_loss: 0.6263
# Epoch 4824/5000
#  - 0s - loss: 0.3802 - val_loss: 0.6193
# Epoch 4825/5000
#  - 0s - loss: 0.3661 - val_loss: 0.6195
# Epoch 4826/5000
#  - 0s - loss: 0.3099 - val_loss: 0.6220
# Epoch 4827/5000
#  - 0s - loss: 0.3629 - val_loss: 0.6193
# Epoch 4828/5000
#  - 0s - loss: 0.3347 - val_loss: 0.6233
# Epoch 4829/5000
#  - 0s - loss: 0.3594 - val_loss: 0.6350
# Epoch 4830/5000
#  - 0s - loss: 0.3438 - val_loss: 0.6459
# Epoch 4831/5000
#  - 0s - loss: 0.3597 - val_loss: 0.6362
# Epoch 4832/5000
#  - 0s - loss: 0.3389 - val_loss: 0.6249
# Epoch 4833/5000
#  - 0s - loss: 0.3796 - val_loss: 0.6088
# Epoch 4834/5000
#  - 0s - loss: 0.3300 - val_loss: 0.6021
# Epoch 4835/5000
#  - 0s - loss: 0.3489 - val_loss: 0.5977
# Epoch 4836/5000
#  - 0s - loss: 0.3470 - val_loss: 0.5994
# Epoch 4837/5000
#  - 0s - loss: 0.3797 - val_loss: 0.6041
# Epoch 4838/5000
#  - 0s - loss: 0.3118 - val_loss: 0.6054
# Epoch 4839/5000
#  - 0s - loss: 0.3419 - val_loss: 0.6124
# Epoch 4840/5000
#  - 0s - loss: 0.2997 - val_loss: 0.6165
# Epoch 4841/5000
#  - 0s - loss: 0.3334 - val_loss: 0.6243
# Epoch 4842/5000
#  - 0s - loss: 0.3285 - val_loss: 0.6208
# Epoch 4843/5000
#  - 0s - loss: 0.3531 - val_loss: 0.6115
# Epoch 4844/5000
#  - 0s - loss: 0.3287 - val_loss: 0.6135
# Epoch 4845/5000
#  - 0s - loss: 0.3399 - val_loss: 0.6149
# Epoch 4846/5000
#  - 0s - loss: 0.3317 - val_loss: 0.6001
# Epoch 4847/5000
#  - 0s - loss: 0.3273 - val_loss: 0.5973
# Epoch 4848/5000
#  - 0s - loss: 0.3634 - val_loss: 0.6027
# Epoch 4849/5000
#  - 0s - loss: 0.3442 - val_loss: 0.6061
# Epoch 4850/5000
#  - 0s - loss: 0.3477 - val_loss: 0.6074
# Epoch 4851/5000
#  - 0s - loss: 0.3016 - val_loss: 0.6173
# Epoch 4852/5000
#  - 0s - loss: 0.3358 - val_loss: 0.6082
# Epoch 4853/5000
#  - 0s - loss: 0.3718 - val_loss: 0.6161
# Epoch 4854/5000
#  - 0s - loss: 0.3214 - val_loss: 0.6192
# Epoch 4855/5000
#  - 0s - loss: 0.3542 - val_loss: 0.6220
# Epoch 4856/5000
#  - 0s - loss: 0.3366 - val_loss: 0.6307
# Epoch 4857/5000
#  - 0s - loss: 0.3487 - val_loss: 0.6417
# Epoch 4858/5000
#  - 0s - loss: 0.3253 - val_loss: 0.6441
# Epoch 4859/5000
#  - 0s - loss: 0.3677 - val_loss: 0.6471
# Epoch 4860/5000
#  - 0s - loss: 0.3285 - val_loss: 0.6477
# Epoch 4861/5000
#  - 0s - loss: 0.3717 - val_loss: 0.6414
# Epoch 4862/5000
#  - 0s - loss: 0.2990 - val_loss: 0.6358
# Epoch 4863/5000
#  - 0s - loss: 0.3538 - val_loss: 0.6303
# Epoch 4864/5000
#  - 0s - loss: 0.3221 - val_loss: 0.6336
# Epoch 4865/5000
#  - 0s - loss: 0.3815 - val_loss: 0.6291
# Epoch 4866/5000
#  - 0s - loss: 0.3381 - val_loss: 0.6292
# Epoch 4867/5000
#  - 0s - loss: 0.3283 - val_loss: 0.6260
# Epoch 4868/5000
#  - 0s - loss: 0.3166 - val_loss: 0.6252
# Epoch 4869/5000
#  - 0s - loss: 0.3452 - val_loss: 0.6281
# Epoch 4870/5000
#  - 0s - loss: 0.3841 - val_loss: 0.6192
# Epoch 4871/5000
#  - 0s - loss: 0.3459 - val_loss: 0.6153
# Epoch 4872/5000
#  - 0s - loss: 0.3449 - val_loss: 0.6224
# Epoch 4873/5000
#  - 0s - loss: 0.3441 - val_loss: 0.6292
# Epoch 4874/5000
#  - 0s - loss: 0.3381 - val_loss: 0.6308
# Epoch 4875/5000
#  - 0s - loss: 0.3055 - val_loss: 0.6313
# Epoch 4876/5000
#  - 0s - loss: 0.3352 - val_loss: 0.6305
# Epoch 4877/5000
#  - 0s - loss: 0.3365 - val_loss: 0.6301
# Epoch 4878/5000
#  - 0s - loss: 0.3617 - val_loss: 0.6304
# Epoch 4879/5000
#  - 0s - loss: 0.2971 - val_loss: 0.6228
# Epoch 4880/5000
#  - 0s - loss: 0.3245 - val_loss: 0.6225
# Epoch 4881/5000
#  - 0s - loss: 0.3629 - val_loss: 0.6225
# Epoch 4882/5000
#  - 0s - loss: 0.3336 - val_loss: 0.6069
# Epoch 4883/5000
#  - 0s - loss: 0.3543 - val_loss: 0.5934
# Epoch 4884/5000
#  - 0s - loss: 0.3529 - val_loss: 0.5918
# Epoch 4885/5000
#  - 0s - loss: 0.3566 - val_loss: 0.5955
# Epoch 4886/5000
#  - 0s - loss: 0.3239 - val_loss: 0.5952
# Epoch 4887/5000
#  - 0s - loss: 0.3364 - val_loss: 0.5968
# Epoch 4888/5000
#  - 0s - loss: 0.3731 - val_loss: 0.5951
# Epoch 4889/5000
#  - 0s - loss: 0.3238 - val_loss: 0.5967
# Epoch 4890/5000
#  - 0s - loss: 0.3644 - val_loss: 0.6009
# Epoch 4891/5000
#  - 0s - loss: 0.3063 - val_loss: 0.6109
# Epoch 4892/5000
#  - 0s - loss: 0.3078 - val_loss: 0.6169
# Epoch 4893/5000
#  - 0s - loss: 0.3337 - val_loss: 0.6331
# Epoch 4894/5000
#  - 0s - loss: 0.3170 - val_loss: 0.6436
# Epoch 4895/5000
#  - 0s - loss: 0.3366 - val_loss: 0.6350
# Epoch 4896/5000
#  - 0s - loss: 0.3650 - val_loss: 0.6160
# Epoch 4897/5000
#  - 0s - loss: 0.3144 - val_loss: 0.6115
# Epoch 4898/5000
#  - 0s - loss: 0.3415 - val_loss: 0.6140
# Epoch 4899/5000
#  - 0s - loss: 0.3797 - val_loss: 0.6099
# Epoch 4900/5000
#  - 0s - loss: 0.3219 - val_loss: 0.6100
# Epoch 4901/5000
#  - 0s - loss: 0.3466 - val_loss: 0.6062
# Epoch 4902/5000
#  - 0s - loss: 0.3226 - val_loss: 0.6076
# Epoch 4903/5000
#  - 0s - loss: 0.3005 - val_loss: 0.6101
# Epoch 4904/5000
#  - 0s - loss: 0.3067 - val_loss: 0.6047
# Epoch 4905/5000
#  - 0s - loss: 0.3571 - val_loss: 0.6167
# Epoch 4906/5000
#  - 0s - loss: 0.3343 - val_loss: 0.6283
# Epoch 4907/5000
#  - 0s - loss: 0.3186 - val_loss: 0.6363
# Epoch 4908/5000
#  - 0s - loss: 0.3367 - val_loss: 0.6292
# Epoch 4909/5000
#  - 0s - loss: 0.3294 - val_loss: 0.6273
# Epoch 4910/5000
#  - 0s - loss: 0.3271 - val_loss: 0.6319
# Epoch 4911/5000
#  - 0s - loss: 0.3151 - val_loss: 0.6310
# Epoch 4912/5000
#  - 0s - loss: 0.3604 - val_loss: 0.6323
# Epoch 4913/5000
#  - 0s - loss: 0.3568 - val_loss: 0.6340
# Epoch 4914/5000
#  - 0s - loss: 0.3285 - val_loss: 0.6337
# Epoch 4915/5000
#  - 0s - loss: 0.3829 - val_loss: 0.6327
# Epoch 4916/5000
#  - 0s - loss: 0.3153 - val_loss: 0.6319
# Epoch 4917/5000
#  - 0s - loss: 0.3494 - val_loss: 0.6361
# Epoch 4918/5000
#  - 0s - loss: 0.3388 - val_loss: 0.6329
# Epoch 4919/5000
#  - 0s - loss: 0.3345 - val_loss: 0.6211
# Epoch 4920/5000
#  - 0s - loss: 0.3427 - val_loss: 0.6035
# Epoch 4921/5000
#  - 0s - loss: 0.3309 - val_loss: 0.5966
# Epoch 4922/5000
#  - 0s - loss: 0.3448 - val_loss: 0.6025
# Epoch 4923/5000
#  - 0s - loss: 0.3397 - val_loss: 0.5988
# Epoch 4924/5000
#  - 0s - loss: 0.3249 - val_loss: 0.5917
# Epoch 4925/5000
#  - 0s - loss: 0.3357 - val_loss: 0.5822
# Epoch 4926/5000
#  - 0s - loss: 0.3581 - val_loss: 0.5950
# Epoch 4927/5000
#  - 0s - loss: 0.3528 - val_loss: 0.6113
# Epoch 4928/5000
#  - 0s - loss: 0.3082 - val_loss: 0.6309
# Epoch 4929/5000
#  - 0s - loss: 0.3188 - val_loss: 0.6500
# Epoch 4930/5000
#  - 0s - loss: 0.3222 - val_loss: 0.6481
# Epoch 4931/5000
#  - 0s - loss: 0.3514 - val_loss: 0.6328
# Epoch 4932/5000
#  - 0s - loss: 0.3087 - val_loss: 0.6319
# Epoch 4933/5000
#  - 0s - loss: 0.3559 - val_loss: 0.6291
# Epoch 4934/5000
#  - 0s - loss: 0.3449 - val_loss: 0.6127
# Epoch 4935/5000
#  - 0s - loss: 0.3431 - val_loss: 0.6129
# Epoch 4936/5000
#  - 0s - loss: 0.3469 - val_loss: 0.6139
# Epoch 4937/5000
#  - 0s - loss: 0.3418 - val_loss: 0.6184
# Epoch 4938/5000
#  - 0s - loss: 0.2933 - val_loss: 0.6283
# Epoch 4939/5000
#  - 0s - loss: 0.3482 - val_loss: 0.6382
# Epoch 4940/5000
#  - 0s - loss: 0.3588 - val_loss: 0.6487
# Epoch 4941/5000
#  - 0s - loss: 0.4183 - val_loss: 0.6569
# Epoch 4942/5000
#  - 0s - loss: 0.3521 - val_loss: 0.6393
# Epoch 4943/5000
#  - 0s - loss: 0.3676 - val_loss: 0.6229
# Epoch 4944/5000
#  - 0s - loss: 0.3575 - val_loss: 0.6144
# Epoch 4945/5000
#  - 0s - loss: 0.3875 - val_loss: 0.6221
# Epoch 4946/5000
#  - 0s - loss: 0.3187 - val_loss: 0.6099
# Epoch 4947/5000
#  - 0s - loss: 0.2766 - val_loss: 0.6091
# Epoch 4948/5000
#  - 0s - loss: 0.3307 - val_loss: 0.6189
# Epoch 4949/5000
#  - 0s - loss: 0.3443 - val_loss: 0.6114
# Epoch 4950/5000
#  - 0s - loss: 0.2968 - val_loss: 0.6083
# Epoch 4951/5000
#  - 0s - loss: 0.3553 - val_loss: 0.6266
# Epoch 4952/5000
#  - 0s - loss: 0.3407 - val_loss: 0.6047
# Epoch 4953/5000
#  - 0s - loss: 0.3485 - val_loss: 0.5986
# Epoch 4954/5000
#  - 0s - loss: 0.3186 - val_loss: 0.6040
# Epoch 4955/5000
#  - 0s - loss: 0.3254 - val_loss: 0.6156
# Epoch 4956/5000
#  - 0s - loss: 0.3050 - val_loss: 0.6226
# Epoch 4957/5000
#  - 0s - loss: 0.3276 - val_loss: 0.6325
# Epoch 4958/5000
#  - 0s - loss: 0.3456 - val_loss: 0.6363
# Epoch 4959/5000
#  - 0s - loss: 0.3560 - val_loss: 0.6222
# Epoch 4960/5000
#  - 0s - loss: 0.3713 - val_loss: 0.6266
# Epoch 4961/5000
#  - 0s - loss: 0.3540 - val_loss: 0.6101
# Epoch 4962/5000
#  - 0s - loss: 0.3418 - val_loss: 0.5972
# Epoch 4963/5000
#  - 0s - loss: 0.3031 - val_loss: 0.5901
# Epoch 4964/5000
#  - 0s - loss: 0.3892 - val_loss: 0.5962
# Epoch 4965/5000
#  - 0s - loss: 0.3558 - val_loss: 0.5772
# Epoch 4966/5000
#  - 0s - loss: 0.3778 - val_loss: 0.5887
# Epoch 4967/5000
#  - 0s - loss: 0.3572 - val_loss: 0.5830
# Epoch 4968/5000
#  - 0s - loss: 0.3385 - val_loss: 0.5903
# Epoch 4969/5000
#  - 0s - loss: 0.3877 - val_loss: 0.5975
# Epoch 4970/5000
#  - 0s - loss: 0.3503 - val_loss: 0.6270
# Epoch 4971/5000
#  - 0s - loss: 0.3580 - val_loss: 0.6099
# Epoch 4972/5000
#  - 0s - loss: 0.4348 - val_loss: 0.5967
# Epoch 4973/5000
#  - 0s - loss: 0.3444 - val_loss: 0.5958
# Epoch 4974/5000
#  - 0s - loss: 0.3267 - val_loss: 0.6024
# Epoch 4975/5000
#  - 0s - loss: 0.2966 - val_loss: 0.6088
# Epoch 4976/5000
#  - 0s - loss: 0.3735 - val_loss: 0.6168
# Epoch 4977/5000
#  - 0s - loss: 0.3444 - val_loss: 0.6207
# Epoch 4978/5000
#  - 0s - loss: 0.3220 - val_loss: 0.6159
# Epoch 4979/5000
#  - 0s - loss: 0.3898 - val_loss: 0.6107
# Epoch 4980/5000
#  - 0s - loss: 0.3391 - val_loss: 0.6226
# Epoch 4981/5000
#  - 0s - loss: 0.3551 - val_loss: 0.6530
# Epoch 4982/5000
#  - 0s - loss: 0.3680 - val_loss: 0.6616
# Epoch 4983/5000
#  - 0s - loss: 0.3465 - val_loss: 0.6582
# Epoch 4984/5000
#  - 0s - loss: 0.3514 - val_loss: 0.6551
# Epoch 4985/5000
#  - 0s - loss: 0.3595 - val_loss: 0.6447
# Epoch 4986/5000
#  - 0s - loss: 0.3534 - val_loss: 0.6434
# Epoch 4987/5000
#  - 0s - loss: 0.3871 - val_loss: 0.6450
# Epoch 4988/5000
#  - 0s - loss: 0.3392 - val_loss: 0.6542
# Epoch 4989/5000
#  - 0s - loss: 0.3720 - val_loss: 0.6717
# Epoch 4990/5000
#  - 0s - loss: 0.3751 - val_loss: 0.6596
# Epoch 4991/5000
#  - 0s - loss: 0.3369 - val_loss: 0.6551
# Epoch 4992/5000
#  - 0s - loss: 0.3995 - val_loss: 0.6627
# Epoch 4993/5000
#  - 0s - loss: 0.3097 - val_loss: 0.6587
# Epoch 4994/5000
#  - 0s - loss: 0.3563 - val_loss: 0.6628
# Epoch 4995/5000
#  - 0s - loss: 0.3679 - val_loss: 0.6571
# Epoch 4996/5000
#  - 0s - loss: 0.3913 - val_loss: 0.6455
# Epoch 4997/5000
#  - 0s - loss: 0.3744 - val_loss: 0.6165
# Epoch 4998/5000
#  - 0s - loss: 0.3549 - val_loss: 0.6440
# Epoch 4999/5000
#  - 0s - loss: 0.3459 - val_loss: 0.6226
# Epoch 5000/5000
#  - 0s - loss: 0.3306 - val_loss: 0.6293

# %%
plt.figure(figsize=(10, 8))
plt.title("Dense model training", fontsize=12)
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Test")
plt.grid("on")
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("loss", fontsize=12)
plt.legend(loc="upper right")

# %%
def compare_result(y_pred,y_test):
    '''
        compare prediction for test set in different models

    '''
    #idx = outputs.index(accuracy_col) 
    #'accuracy': count_CC(p[:,idx],y_test[:,idx],threshold = threshold )
    result = pd.DataFrame([{'Model': k ,
                            'MAE': round(mean_absolute_error(p,y_test),4),
                            'RMSE' :  round(sqrt(mean_squared_error(p,y_test)),4) ,
                            'DENORMALIZED' : mean_absolute_error(ouput_de_normlizer(p),
                                                                    ouput_de_normlizer(y_test))}
                            for k,p in y_pred.iteritems()
                          ])
    return result[['Model','MAE','RMSE','DENORMALIZED']].set_index('Model').sort_values('DENORMALIZED',ascending =False)

# %%
compare_result(y_pred,y_test)
# Out:
#                   MAE    RMSE  DENORMALIZED
# Model
# Crude Avrage   0.6242  0.9553      0.023248
# Lasso          0.6252  0.9491      0.023175
# knn            0.6261  0.9449      0.023156
# Random Forest  0.6142  0.9428      0.022693
# DNN            0.4281  0.7933      0.011863

# %%
outputs.index('max_r') 
p = pd.DataFrame(y_pred['DNN'],columns=outputs)
r = pd.DataFrame(y_test,columns=outputs).rename(lambda x: x+'_test',axis='columns')
count_CC(list(p['max_r']),list(r['max_r_test']))

plt.scatter(map(ff,list(p['max_r'])),map(ff,list(r['max_r_test'])))

# %%
idx = outputs.index('max_r') 
count_CC(y_pred['DNN'][:,idx],
         y_test[:,idx])

count_CC(ouput_de_normlizer(y_pred['DNN'])[:,0], ouput_de_normlizer(y_test)[:,0])

count_CC(ouput_de_normlizer(y_pred['DNN'])[:,1], ouput_de_normlizer(y_test)[:,1])
# Out:
# {'DD': 0, 'DU': 0, 'UD': 0, 'UU': 0.8588235294117628}

# %%
def ff(x):
    c =15.0
    if x>.005:
        return 1+np.random.normal()/c
    elif x<-.005:
        return -1+np.random.normal()/c
    else:
        return np.random.normal()/c

# %%
def count_CC(x,y, threshold =.002):
    delta = threshold
    N=len(x)
    result = {'UU':0,'UD':0,'DU':0,'DD':0}
    for i in range(len(x)):
        if (x[i] > delta ) and (y[i]> delta):
            result['UU'] +=1.0/N
        if (x[i] > delta ) and (y[i]< -delta):
            result['UD'] +=1.0/N
        if (x[i] < -delta ) and (y[i]> delta):
            result['DU'] +=1.0/N
        if (x[i] < -delta ) and (y[i]<- delta):
            result['DD'] +=1.0/N
    accuracy = (result['UU']+result['DD'])/(sum(result.values()))
    return result

# %%
pd.concat([p[['max_r','min_r']],r[['max_r_test','min_r_test']]],axis=1).plot.scatter('max_r','max_r_test')

# %%
pd.concat([p[['max_r','min_r']],r[['max_r_test','min_r_test']]],axis=1).plot.scatter('min_r','min_r_test')

# %%
p = pd.DataFrame(y_pred['Crude Average'],columns=outputs)
r = pd.DataFrame(y_test,columns=outputs).rename(lambda x: x+'_test',axis='columns')
#plt.scatter(map(ff,list(p['daily_r'])),map(ff,list(r['daily_r_test'])))
rr = pd.concat([p[['max_r','min_r']],r[['max_r_test','min_r_test']]],axis=1)
(abs((rr['max_r']-rr['max_r_test']))).describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-68057020317a> in <module>()
# ----> 1 p = pd.DataFrame(y_pred['Crude Average'],columns=outputs)
#       2 r = pd.DataFrame(y_test,columns=outputs).rename(lambda x: x+'_test',axis='columns')
#       3 #plt.scatter(map(ff,list(p['daily_r'])),map(ff,list(r['daily_r_test'])))
#       4 rr = pd.concat([p[['max_r','min_r']],r[['max_r_test','min_r_test']]],axis=1)
#       5 (abs((rr['max_r']-rr['max_r_test']))).describe()
#
# KeyError: 'Crude Average'

# %%
p = pd.DataFrame(y_pred['DNN'],columns=outputs)
r = pd.DataFrame(y_test,columns=outputs).rename(lambda x: x+'_test',axis='columns')
#plt.scatter(map(ff,list(p['daily_r'])),map(ff,list(r['daily_r_test'])))
rr = pd.concat([p[['max_r','min_r']],r[['max_r_test','min_r_test']]],axis=1)
(abs((rr['max_r']-rr['max_r_test']))).describe()
# Out:
# count    170.000000
# mean       0.336848
# std        0.453913
# min        0.002722
# 25%        0.075238
# 50%        0.218104
# 75%        0.417285
# max        4.396992
# dtype: float64

# %%
import statsmodels.api as sm

# %%
results = sm.OLS((np.array(pd.DataFrame(y_train)[0])) , pd.DataFrame(X_train,columns=inputs)['Open_gush']).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     9.481
# Date:                Mon, 10 Dec 2018   Prob (F-statistic):            0.00224
# Time:                        17:17:27   Log-Likelihood:                -496.93
# No. Observations:                 343   AIC:                             995.9
# Df Residuals:                     342   BIC:                             999.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Open_gush     -0.1775      0.058     -3.079      0.002      -0.291      -0.064
# ==============================================================================
# Omnibus:                      218.009   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1610.291
# Skew:                          -2.694   Prob(JB):                         0.00
# Kurtosis:                      12.146   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.plot((np.array(pd.DataFrame(y_train)[0])) , pd.DataFrame(X_train,columns=inputs)['Open_gush'],'o')

# %%
pd.concat([pd.DataFrame(y_train,columns=outputs) , pd.DataFrame(X_train,columns=inputs)['Open_gush']],axis=1).plot.scatter('Open_gush','min_r'
                        )
